# %% [markdown]
# # Now You Code 3: Syracuse Historical Weather
#
# Write a program to prompt a user to input a date and time string, and then  it should report the temperature and weather conditions at that day and time for Syracuse, NY.
#
# To lookup the weather you will need to use the Dark Sky Time Machine: https://darksky.net/dev/docs/time-machine
#
# The date and time that the user inputs must be in the following format: `YYYY-MM-DDThh:mm:ss` for example January 7, 2016 at 4:30pm would be: `2016-01-07T16:30:00`
#
# Be sure to use the GPS coordinates for Syracuse, NY which are (lat=43.048122,lng=-76.147424)
#
# Example Run (Based on the exchange rates from 2017-03-06:
#
# ```
# Enter the amount in USD you wish to exchange: 100
# 100.00 in USD is 94.41 in EUR
# 100.00 in USD is 81.48 in GBP
# ```

# %%
# Write your plan (todo list) here
#import requests
#set function and call the function
#take out the information from the provided url

# %%
#todo write code here. 
import requests

#first I write these



def darksky_weather():
    key = '3038a571280c82aa87bc9ea715500d8c' # sign up for your own key at https://darksky.net/dev 
    url='https://api.darksky.net/forecast/3038a571280c82aa87bc9ea715500d8c/43.048122,-76.147424,2016-01-07T16:30:00'
    response = requests.get(url)
    weather = response.json()
    return weather


darksky_weather()
# Out:
# {'currently': {'apparentTemperature': 34.96,
#   'cloudCover': 0.27,
#   'dewPoint': 17.27,
#   'humidity': 0.48,
#   'icon': 'partly-cloudy-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'pressure': 1023.71,
#   'summary': 'Partly Cloudy',
#   'temperature': 34.96,
#   'time': 1452202200,
#   'visibility': 10,
#   'windBearing': 74,
#   'windSpeed': 1.73},
#  'daily': {'data': [{'apparentTemperatureMax': 37.96,
#     'apparentTemperatureMaxTime': 1452196800,
#     'apparentTemperatureMin': 11.17,
#     'apparentTemperatureMinTime': 1452168000,
#     'cloudCover': 0.16,
#     'dewPoint': 15.93,
#     'humidity': 0.68,
#     'icon': 'clear-day',
#     'moonPhase': 0.92,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'pressure': 1025.37,
#     'summary': 'Clear throughout the day.',
#     'sunriseTime': 1452170226,
#     'sunsetTime': 1452203187,
#     'temperatureMax': 37.96,
#     'temperatureMaxTime': 1452196800,
#     'temperatureMin': 17.32,
#     'temperatureMinTime': 1452164400,
#     'time': 1452142800,
#     'visibility': 9.99,
#     'windBearing': 120,
#     'windSpeed': 2.48}]},
#  'flags': {'isd-stations': ['714300-99999',
#    '718200-99999',
#    '725146-54773',
#    '725150-04725',
#    '725155-94761',
#    '725156-14748',
#    '725190-14771',
#    '725194-54778',
#    '725196-64775',
#    '726227-94790',
#    '743700-14715',
#    '995960-99999',
#    '997190-99999',
#    '997264-99999',
#    '998009-99999',
#    '999999-64758'],
#   'sources': ['isd'],
#   'units': 'us'},
#  'hourly': {'data': [{'apparentTemperature': 20.15,
#     'cloudCover': 0.18,
#     'dewPoint': 14.27,
#     'humidity': 0.78,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1027.67,
#     'summary': 'Clear',
#     'temperature': 20.15,
#     'time': 1452142800,
#     'visibility': 10,
#     'windBearing': 159,
#     'windSpeed': 2.43},
#    {'apparentTemperature': 20.43,
#     'cloudCover': 0.18,
#     'dewPoint': 14.44,
#     'humidity': 0.77,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1027.13,
#     'summary': 'Clear',
#     'temperature': 20.43,
#     'time': 1452146400,
#     'visibility': 10,
#     'windBearing': 166,
#     'windSpeed': 1.82},
#    {'apparentTemperature': 13.34,
#     'cloudCover': 0.18,
#     'dewPoint': 15.04,
#     'humidity': 0.79,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1026.85,
#     'summary': 'Clear',
#     'temperature': 20.52,
#     'time': 1452150000,
#     'visibility': 10,
#     'windBearing': 205,
#     'windSpeed': 5.23},
#    {'apparentTemperature': 14.01,
#     'cloudCover': 0,
#     'dewPoint': 14.42,
#     'humidity': 0.8,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1027.01,
#     'summary': 'Clear',
#     'temperature': 19.52,
#     'time': 1452153600,
#     'visibility': 10,
#     'windBearing': 144,
#     'windSpeed': 3.75},
#    {'apparentTemperature': 19.18,
#     'cloudCover': 0.18,
#     'dewPoint': 14.87,
#     'humidity': 0.83,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1026.64,
#     'summary': 'Clear',
#     'temperature': 19.18,
#     'time': 1452157200,
#     'visibility': 10,
#     'windBearing': 132,
#     'windSpeed': 2.78},
#    {'apparentTemperature': 14.06,
#     'cloudCover': 0.18,
#     'dewPoint': 13.59,
#     'humidity': 0.8,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1026.54,
#     'summary': 'Clear',
#     'temperature': 18.78,
#     'time': 1452160800,
#     'visibility': 10,
#     'windBearing': 127,
#     'windSpeed': 3.17},
#    {'apparentTemperature': 12.25,
#     'cloudCover': 0.18,
#     'dewPoint': 12.69,
#     'humidity': 0.82,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1026.61,
#     'summary': 'Clear',
#     'temperature': 17.32,
#     'time': 1452164400,
#     'visibility': 10,
#     'windBearing': 96,
#     'windSpeed': 3.26},
#    {'apparentTemperature': 11.17,
#     'cloudCover': 0.45,
#     'dewPoint': 12.51,
#     'humidity': 0.79,
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1026.65,
#     'summary': 'Partly Cloudy',
#     'temperature': 18.01,
#     'time': 1452168000,
#     'visibility': 10,
#     'windBearing': 104,
#     'windSpeed': 4.56},
#    {'apparentTemperature': 11.71,
#     'cloudCover': 0.05,
#     'dewPoint': 12.75,
#     'humidity': 0.82,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1026.74,
#     'summary': 'Clear',
#     'temperature': 17.33,
#     'time': 1452171600,
#     'visibility': 10,
#     'windBearing': 110,
#     'windSpeed': 3.61},
#    {'apparentTemperature': 14.41,
#     'cloudCover': 0,
#     'dewPoint': 13.65,
#     'humidity': 0.77,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1026.77,
#     'summary': 'Clear',
#     'temperature': 19.63,
#     'time': 1452175200,
#     'visibility': 10,
#     'windBearing': 95,
#     'windSpeed': 3.57},
#    {'apparentTemperature': 19.65,
#     'cloudCover': 0.41,
#     'dewPoint': 16.1,
#     'humidity': 0.7,
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1026.71,
#     'summary': 'Partly Cloudy',
#     'temperature': 24.38,
#     'time': 1452178800,
#     'visibility': 10,
#     'windBearing': 106,
#     'windSpeed': 3.71},
#    {'apparentTemperature': 24.99,
#     'cloudCover': 0,
#     'dewPoint': 17.06,
#     'humidity': 0.6,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1026.28,
#     'summary': 'Clear',
#     'temperature': 29.02,
#     'time': 1452182400,
#     'visibility': 10,
#     'windBearing': 125,
#     'windSpeed': 3.71},
#    {'apparentTemperature': 30.97,
#     'cloudCover': 0,
#     'dewPoint': 17.2,
#     'humidity': 0.5,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1025.49,
#     'summary': 'Clear',
#     'temperature': 33.64,
#     'time': 1452186000,
#     'visibility': 10,
#     'windBearing': 169,
#     'windSpeed': 3.15},
#    {'apparentTemperature': 32.89,
#     'cloudCover': 0.42,
#     'dewPoint': 17.61,
#     'humidity': 0.48,
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1024.67,
#     'summary': 'Partly Cloudy',
#     'temperature': 35.38,
#     'time': 1452189600,
#     'visibility': 10,
#     'windBearing': 188,
#     'windSpeed': 3.19},
#    {'apparentTemperature': 37.2,
#     'cloudCover': 0.03,
#     'dewPoint': 18.25,
#     'humidity': 0.46,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.67,
#     'summary': 'Clear',
#     'temperature': 37.2,
#     'time': 1452193200,
#     'visibility': 10,
#     'windBearing': 111,
#     'windSpeed': 2.89},
#    {'apparentTemperature': 37.96,
#     'cloudCover': 0,
#     'dewPoint': 17.92,
#     'humidity': 0.44,
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.49,
#     'summary': 'Clear',
#     'temperature': 37.96,
#     'time': 1452196800,
#     'visibility': 10,
#     'windBearing': 39,
#     'windSpeed': 1.63},
#    {'apparentTemperature': 36.27,
#     'cloudCover': 0.54,
#     'dewPoint': 17.24,
#     'humidity': 0.45,
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.6,
#     'summary': 'Partly Cloudy',
#     'temperature': 36.27,
#     'time': 1452200400,
#     'visibility': 10,
#     'windBearing': 75,
#     'windSpeed': 2.17},
#    {'apparentTemperature': 33.66,
#     'cloudCover': 0,
#     'dewPoint': 17.24,
#     'humidity': 0.5,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.82,
#     'summary': 'Clear',
#     'temperature': 33.66,
#     'time': 1452204000,
#     'visibility': 10,
#     'windBearing': 72,
#     'windSpeed': 1.31},
#    {'apparentTemperature': 30.98,
#     'cloudCover': 0,
#     'dewPoint': 17.74,
#     'humidity': 0.57,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1024.04,
#     'summary': 'Clear',
#     'temperature': 30.98,
#     'time': 1452207600,
#     'visibility': 10,
#     'windBearing': 91,
#     'windSpeed': 1.68},
#    {'apparentTemperature': 25.57,
#     'cloudCover': 0.61,
#     'dewPoint': 19.95,
#     'humidity': 0.69,
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.89,
#     'summary': 'Mostly Cloudy',
#     'temperature': 28.76,
#     'time': 1452211200,
#     'visibility': 10,
#     'windBearing': 103,
#     'windSpeed': 3.05},
#    {'apparentTemperature': 21.61,
#     'cloudCover': 0,
#     'dewPoint': 17.3,
#     'humidity': 0.69,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1024.04,
#     'summary': 'Clear',
#     'temperature': 26.2,
#     'time': 1452214800,
#     'visibility': 9.96,
#     'windBearing': 98,
#     'windSpeed': 3.82},
#    {'apparentTemperature': 19.62,
#     'cloudCover': 0,
#     'dewPoint': 17.43,
#     'humidity': 0.74,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.93,
#     'summary': 'Clear',
#     'temperature': 24.48,
#     'time': 1452218400,
#     'visibility': 9.96,
#     'windBearing': 108,
#     'windSpeed': 3.82},
#    {'apparentTemperature': 23.78,
#     'cloudCover': 0.17,
#     'dewPoint': 16.81,
#     'humidity': 0.74,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.51,
#     'summary': 'Clear',
#     'temperature': 23.78,
#     'time': 1452222000,
#     'visibility': 9.96,
#     'windBearing': 91,
#     'windSpeed': 2.9},
#    {'apparentTemperature': 21.79,
#     'cloudCover': 0.18,
#     'dewPoint': 16.17,
#     'humidity': 0.79,
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'pressure': 1023.17,
#     'summary': 'Clear',
#     'temperature': 21.79,
#     'time': 1452225600,
#     'visibility': 9.91,
#     'windBearing': 96,
#     'windSpeed': 2.54}],
#   'icon': 'clear-day',
#   'summary': 'Clear throughout the day.'},
#  'latitude': 43.048122,
#  'longitude': -76.147424,
#  'offset': -5,
#  'timezone': 'America/New_York'}

# %%
time=input("Enter a time in the future or the past to check the wheather in syracuse(e.g. YYYY-MM-DDThh:mm:ss)")
function=darksky_weather()
history_weather=function['currently']
print("The weather was or is:",history_weather['summary'])
print("temperature:",history_weather['temperature'])
# Out:
# Enter a time in the future or the past to check the wheather in syracuse(e.g. YYYY-MM-DDThh:mm:ss)2016-01-07T16:30:00
# The weather was or is: Partly Cloudy
# temperature: 34.96
