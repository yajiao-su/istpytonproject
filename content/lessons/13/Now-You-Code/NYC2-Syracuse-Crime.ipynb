# %% [markdown]
# ## Now You Code 2: Syracuse Crime Data
#
# In this second now you code you will explore the plot.ly engine in detail using Syracuse, NY FBI crime data.

# %%
import plotly.plotly as py    
import plotly.graph_objs as go  
import cufflinks as cf
import pandas as pd

# %%
crime = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/crime/syracuse-crime-data-1985-2012.csv')
crime.sample(10)
# Out:
#     Year  Months  Population  Violent crime total  \
# 13  1998      12      154911                 1423
# 11  1996      12      160033                 1398
# 12  1997      12      159610                 1430
# 20  2005      12      143306                 1570
# 0   1985      12      164659                 1013
# 8   1993      12      163626                 1361
# 14  1999      12      152393                 1439
# 23  2008      12      138211                 1366
# 1   1986      12      164560                 1108
# 10  1995      12      159603                 1467
#
#     Murder and nonnegligent Manslaughter  Forcible rape  Robbery  \
# 13                                    12             49      465
# 11                                    15             62      579
# 12                                    15             55      586
# 20                                    19             73      554
# 0                                     12             80      551
# 8                                     18             79      561
# 14                                     9             47      483
# 23                                    24             71      419
# 1                                      9             61      552
# 10                                    18             84      633
#
#     Aggravated assault  Property crime total  Burglary     ...       \
# 13                 897                  8526      2194     ...
# 11                 742                  9601      2821     ...
# 12                 774                  9075      2388     ...
# 20                 924                  6486      1867     ...
# 0                  370                 11037      3741     ...
# 8                  703                  9754      2824     ...
# 14                 900                  7429      2016     ...
# 23                 852                  6165      1938     ...
# 1                  486                 11097      3646     ...
# 10                 732                  9873      3048     ...
#
#     Violent Crime rate  Murder and nonnegligent manslaughter rate  \
# 13               918.6                                        7.7
# 11               873.6                                        9.4
# 12               895.9                                        9.4
# 20              1095.6                                       13.3
# 0                615.2                                        7.3
# 8                831.8                                       11.0
# 14               944.3                                        5.9
# 23               988.3                                       17.4
# 1                673.3                                        5.5
# 10               919.2                                       11.3
#
#     Forcible rape rate  Robbery rate  Aggravated assault rate  \
# 13                31.6         300.2                    579.0
# 11                38.7         361.8                    463.7
# 12                34.5         367.1                    484.9
# 20                50.9         386.6                    644.8
# 0                 48.6         334.6                    224.7
# 8                 48.3         342.9                    429.6
# 14                30.8         316.9                    590.6
# 23                51.4         303.2                    616.4
# 1                 37.1         335.4                    295.3
# 10                52.6         396.6                    458.6
#
#     Property crime rate  Burglary rate  Larceny-theft rate  \
# 13               5503.8         1416.3              3665.3
# 11               5999.4         1762.8              3711.7
# 12               5685.7         1496.1              3731.6
# 20               4526.0         1302.8              2539.3
# 0                6702.9         2272.0              4172.3
# 8                5961.2         1725.9              3885.7
# 14               4874.9         1322.9              3059.9
# 23               4460.6         1402.2              2695.2
# 1                6743.4         2215.6              4225.8
# 10               6186.0         1909.7              3779.4
#
#     Motor vehicle theft rate  Unnamed: 21
# 13                     422.2          NaN
# 11                     524.9          NaN
# 12                     458.0          NaN
# 20                     683.9          NaN
# 0                      258.7          NaN
# 8                      349.6          NaN
# 14                     492.1          NaN
# 23                     363.2          NaN
# 1                      302.0          NaN
# 10                     496.9          NaN
#
# [10 rows x 22 columns]

# %%
# Make a line plot of population over the years, using cufflinks crime.iplot()
# set the titles on x "Year, Y "Population" and cart title " Syracuse Population" 
# TODO: replace the ???? with appropriate values to render the chart
crime.iplot(kind = 'scatter', x = 'Year', y = 'Population', title='Syracuse Population',xTitle='Year',yTitle='Population')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-4-a1d55fa4405a> in <module>()
#       2 # set the titles on x "Year, Y "Population" and cart title " Syracuse Population"
#       3 # TODO: replace the ???? with appropriate values to render the chart
# ----> 4 crime.iplot(kind = 'scatter', x = 'Year', y = 'Population', title='Syracuse Population',xTitle='Year',yTitle='Population')
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/cufflinks/plotlytools.py in _iplot(self, data, layout, filename, sharing, kind, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     955                 return py.plot(figure,sharing=sharing,filename=filename,validate=validate,auto_open=False)
#     956         else:
# --> 957                 return iplot(figure,sharing=sharing,filename=filename,validate=validate,online=online)
#     958
#     959
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/cufflinks/plotlytools.py in iplot(data_or_figure, validate, sharing, filename, online, **kwargs)
#    1099                         filename='Plotly Playground {0}'.format(time.strftime("%Y-%m-%d %H:%M:%S"))
#    1100 		return py.iplot(data_or_figure,validate=validate,sharing=sharing,
# -> 1101 						filename=filename)
#    1102
#    1103 def _ta_figure(self,**kwargs):
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     132     if 'auto_open' not in plot_options:
#     133         plot_options['auto_open'] = False
# --> 134     url = plot(figure_or_data, **plot_options)
#     135
#     136     if isinstance(figure_or_data, dict):
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     225     data = fig.get('data', [])
#     226     plot_options['layout'] = fig.get('layout', {})
# --> 227     response = v1.clientresp(data, **plot_options)
#     228
#     229     # Check if the url needs a secret key
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/plotly/api/v1/utils.py in validate_response(response)
#      36         message = content if content else 'No Content'
#      37
# ---> 38     raise exceptions.PlotlyRequestError(message, status_code, content)
#      39
#      40
#
# PlotlyRequestError: Hey there! You've hit one of our API request limits.
#
# To get unlimited API calls(10,000/day), please upgrade to a paid plan.
#
# UPGRADE HERE: https://goo.gl/i7glmM
#
# Thanks for using Plotly! Happy Plotting!

# %%
# Now plot the same thing using plot.ly without cufflinks, again filling in the templates. Using plot.ly takes more effort but
# you have more control / flexibility over how the plots are rendered.
plot_data = [
    go.Scatter(x=crime['Year'], y=crime['Population'], mode="lines+markers", name="Syracuse Population", marker=dict(color='red')),
]

py.iplot({ 'data': plot_data,
            'layout': {
               'title': 'Syracuse Population',
               'xaxis': {
                 'title': 'Year'},
               'yaxis': {
                'title': 'Population'}
        }})
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-5-9632dcb6b770> in <module>()
#      11                  'title': 'Year'},
#      12                'yaxis': {
# ---> 13                 'title': 'Population'}
#      14         }})
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     132     if 'auto_open' not in plot_options:
#     133         plot_options['auto_open'] = False
# --> 134     url = plot(figure_or_data, **plot_options)
#     135
#     136     if isinstance(figure_or_data, dict):
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     225     data = fig.get('data', [])
#     226     plot_options['layout'] = fig.get('layout', {})
# --> 227     response = v1.clientresp(data, **plot_options)
#     228
#     229     # Check if the url needs a secret key
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# /Users/yanruijiao/miniconda3/lib/python3.5/site-packages/plotly/api/v1/utils.py in validate_response(response)
#      36         message = content if content else 'No Content'
#      37
# ---> 38     raise exceptions.PlotlyRequestError(message, status_code, content)
#      39
#      40
#
# PlotlyRequestError: Hey there! You've hit one of our API request limits.
#
# To get unlimited API calls(10,000/day), please upgrade to a paid plan.
#
# UPGRADE HERE: https://goo.gl/i7glmM
#
# Thanks for using Plotly! Happy Plotting!

# %%
# Now create a line plot of "Robbery rate" versus "Motor vehicle theft rate" over time.
# NOTE: you will need two series in your plot_data 
plot_data = [
    go.Scatter(x=crime['Year'], y=crime['Robbery rate'], mode="lines+markers", name="Robbery rate", marker=dict(color='red')),
    go.Scatter(x=crime['Year'],y=crime['Motor vehicle theft rate'], mode="lines+markers", name="Motor vehicle theft rate", marker=dict(color='blue')),
]
py.iplot({ 'data': plot_data,
            'layout': {
               'title': 'Crime Rate',
               'xaxis': {
                 'title': 'Year'},
               'yaxis': {
                'title': 'Rate'}
        }})

# %%
Crime_metric=input("Enter a crime metric here")
Crimedoc=['Year','Months','Population''Violent crime total','Murder and nonnegligent Manslaughter','Forcible rape',
          'Robbery','Aggravated assault','Property crime total','Burglary','Violent Crime rate''Murder and nonnegligent',
          'manslaughter rate','Forcible rape rate','Robbery rate','Aggravated assault rate','Property crime rate',
          'Burglary rate','Larceny-theft rate','Motor vehicle theft rate','Unnamed: 21']
Crimedoc_handler=[]
for i in range(len(Crimedoc)):
    print(selection[i])
   
if Crimedoc.count(Crime_metric)==1:
    plot_data=[
        go.Scatter(x=crime['Year'],y=Crime[Crime_metric],mode="lines+markers",name="rate", marker=dict(color='red'))

    ]
    py.iplot({ 'data': plot_data,
                'layout': {
                   'title': 'Crime Rate',
                   'xaxis': {
                     'title': 'Year'},
                   'yaxis': {
                    'title': 'Rate'}
            }})

else:
    print("That's not a crime metric ")
