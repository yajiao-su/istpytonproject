# %% [markdown]
# # In-Class Coding Lab: Scrape NASDAQ Stock Quotes
#
# For this lab we will walk you through scraping stock data from the NASDAQ website: http://www.nasdaq.com/
#
# We will walk you through the process and when you're done you'll be tasked with creating a program which when given an NASDAQ symbol will retrieve the name of the stock, price, and percent change.
#
# While we work through the example, we will use Amazon.com's stock symbol:`amzn`
#
# For a list of NASDAQ stocks to try with the completed program, see here: http://www.cnbc.com/nasdaq-100/
#
#
# ## Our plan
#
# Here's our plan for a given stock symbol, for example `amzn` :
#
# 1. use Requests to get HTML from this page http://www.nasdaq.com/symbol/amzn
# 2. use BeautifulSoup4 to extract data from the site. save the data we extract into a dict
# 3. print the stock info from the dict
#
# We will write each step as its own function below

# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
# !pip install lxml
# Out:
# Requirement already satisfied (use --upgrade to upgrade): lxml in /Users/yanruijiao/miniconda3/lib/python3.5/site-packages
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Use Requests to get HTML
#
# Here's the code:

# %%
symbol = "amzn"
url = 'http://www.nasdaq.com/symbol/' + symbol
response = requests.get(url)
if response.ok:
    print (response.text)
else:
    print ("Error retrieving " + url)
# Out:
# <!doctype html>
# <html lang="en-us" class="inner no-js" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml">
# <head>
# <script>
# (function(){
# var is_chrome;
# if(typeof navigator.vendor!="undefined")
# 	is_chrome = ((navigator.userAgent.toLowerCase().indexOf('chrome') > -1) &&(navigator.vendor.toLowerCase().indexOf("google") > -1));
# else
# 	is_chrome = false;
# if(is_chrome)
# {
# //instart
# //copyright Tue Apr 25 2017 17:02:36 GMT+0000 (UTC)
# (function(f){(function(){var C="undefined"===typeof IXC_115_9954108064986444||"undefined"===typeof IXC_115_9954108064986444.CanRun||"_115_9954108064986444"!==IXC_115_9954108064986444._115_9954108064986444||IXC_115_9954108064986444.CanRun("abd");if(C)try{(f.IXC_115_9954108064986444=f.IXC_115_9954108064986444||{})._115_9954108064986444="_115_9954108064986444",f[atob("SU5TVEFSVA==")+"_TARGET_NAME"]="abd",f[atob("STExQw==")]=f[atob("STExQw==")]||{}}catch(O){console.error(O)}else{var D="abd"!==f[atob("SU5TVEFSVA==")+
# "_TARGET_NAME"],r="double nanovisor injection: abd after "+f[atob("SU5TVEFSVA==")+"_TARGET_NAME"];D&&console.log(r);"function"!==typeof f[atob("SU5TVEFSVA==")].Init&&(f[atob("SU5TVEFSVA==")].Init=function(){D&&console.error("ignored Init call after "+r)})}return C})()&&function(){function C(b,a){return"object"!==typeof a||Array.isArray(a)?a:la(a,b,C)}function D(){return[]}function r(){return 1===t.c}function O(){return 4===t.c}function P(b){x=new ma(b);t=x.V;E=x.Xa;return x}function k(b){return b.split("").filter(function(a,
# b){return 0===b%2}).reverse().join("")}function y(b,a,c){if(!b&&(console.error(a),(b=D(2))&&0<b.length&&console.log(b),na&&!c))throw a;}function l(b,a){function c(){this.constructor=b}Ra(b,a);b.prototype=null===a?Object.create(a):(c.prototype=a.prototype,new c)}function u(b,a){b=b.split(".");for(var c=f||{},d,e=0;e<b.length-1;++e){d=b[e];if(!c)return;var g=c[d]||{};try{c[d]=g}catch(h){}c=g}d=b[b.length-1];if(c){y(!!d,"In Export, name not defined");try{c[d]=a}catch(h){}}}function Sa(b){b=b.split(".");
# for(var a=f,c,d=0;a&&d<b.length-1;++d)if(c=b[d],a=a[c],!a)return;c=b[b.length-1];y(!!a&&!!c,"In Deport, obj or name not defined");try{var e=Object.getOwnPropertyDescriptor(a,c);e&&e.writable&&delete a[c]||(a[c]=void 0)}catch(g){}}function ca(){return f.document.currentScript||f.document.scripts[document.scripts.length-1]}function Ta(){if(F&&G&&F.nextSibling===G)for(var b=G.nextSibling,a=F;a!=b;){var c=a,a=a.nextSibling;c.parentNode.removeChild(c)}Sa(da);u(da+".Init",function(){})}function p(b,a,c){var d=
# {};d.Type=b;d[m]=a;c&&(d[oa]=c);return d}function Ua(){return new z(function(b){function a(a){var d=!1;"load"===a.type?d=!1:"error"===a.type&&(d=!0);b(p(Va,d,a.currentTarget.src));c&&(a=a.target)&&a.parentNode&&a.parentNode.removeChild(a)}var c=4===t.c&&3===E.c,d=document.createElement("img");d.onload=a;d.onerror=a;var e=Math.floor(Math.random()*H.length);d.src=H[e]+"?"+pa[Math.floor(Math.random()*pa.length)];c&&document.body.appendChild(d);1<H.length&&H.splice(e,1)})}function qa(b,a){return new z(function(c){var d=
# "script"===b?Wa:Xa,e=O();if(r()||e){var g;e&&(g=setTimeout(function(){c(p(d,!1,"Timed out on error"))},500));var h=function(a){e&&clearTimeout(g);var b=!1;"load"===a.type?b=!1:"error"===a.type&&(b=!0);c(p(d,b,a.currentTarget.href));(a=a.target)&&a.parentNode&&a.parentNode.removeChild(a)},f=document.createElement("link");f.onload=h;f.onerror=h;f.rel="preload";f.as=b;h=Math.floor(Math.random()*a.length);f.href=a[h];v&&v.parentNode&&v.parentNode.insertBefore(f,v);1<a.length&&a.splice(h,1)}else c(p(d,
# !1,"Neither Chrome nor Safari"))})}function Ya(){new z(function(b){var a=document.createElement("iframe");a.src=f.atob("Ly90cGMuZ29vZ2xlc3luZGljYXRpb24uY29tL3NhZmVmcmFtZS8=")+f.atob("MS0wLTU=")+f.atob("L2h0bWwvY29udGFpbmVyLmh0bWw=");a.style.height="1px";a.style.width="1px";a.style.left="-555px";a.style.top="-555px";a.style.display="block";a.scrolling="no";a.frameBorder="0";var c=f.atob("PHNjcmlwdD53aW5kb3cucGFyZW50ICYmIHdpbmRvdy5wYXJlbnQucG9zdE1lc3NhZ2UoIg==")+f.atob("aTEwY09L")+f.atob("IiwgICIqIik8XC9zY3JpcHQ+"),
# d=setTimeout(function(){b(p(ra,!1,"Disabled"))},5E3),e=sa();a.name=f.atob("MS0wLTU=")+";"+c.length+";"+c;f.addEventListener("message",function(){b(p(ra,!1,String(sa()-e)));clearTimeout(d)},!1);v&&v.parentNode&&v.parentNode.insertBefore(a,v)})}function Za(){return new z(function(b){var a=ta[Math.floor(Math.random()*ta.length)],c=document.createElement(a[0]);c.id=a[1];c.style.width="1px";c.style.height="1px";c.style.top="-555px";c.style.left="-555px";c.style.display="block";var d=setInterval(function(){document&&
# document.body&&(document.body.appendChild(c),clearInterval(d),setTimeout(function(){var a=getComputedStyle(c),d,h=!1;if("none"===a.display||(d=a.getPropertyValue("-moz-binding"))&&-1!==d.indexOf("abp-elemhidehit"))h=!0;b(p("ELEMENT",h));c&&c.parentNode&&c.parentNode.removeChild(c)},200))},10)})}function $a(){return new z(function(b){var a=0;if(!r()||Object.getOwnPropertyDescriptor(Element.prototype,f.atob("c2hhZG93Um9vdA=="))[f.atob("Z2V0")].name===f.atob("Z2V0"))return b(p(Q,!1)),!1;try{new (f[f.atob("V2ViU29ja2V0")])({toString:function(){a++}})}catch(c){}if(2<=
# a)return b(p(Q,!0)),!0;b(p(Q,!1));return!1})}function ab(b){var a;void 0===a&&(a=bb);var c=new a.lb;b.onload&&(c.onload=function(){return b.onload(new ea(c,b))});b.onerror&&(c.onerror=function(){return b.onload(new ea(c,b))});if(b.za)for(var d=0;d<b.za.length;d++)c.setRequestHeader(b.za[d].m,this.za[d].Mc);c.withCredentials=!!b.credentials;a.Nb.call(c,b.method,b.url,!1!==b.async);d=b.body&&JSON.stringify(b.body);a.Vb.call(c,d);!1===b.async&&new ea(c,b)}function R(b){var a=typeof b;if(b&&("object"===
# a||"function"===a)&&!cb.call(b,"__ext")){if(b instanceof NodeList||b instanceof HTMLCollection){for(var a=b.length,c=0;c<a;c++)R(b[c]);return b}a=void 0;c=b.nodeType,1===c&&(a=db[b.nodeName]),a||(a=eb[c]),a||(a=b.__pext);a&&(c={Nc:{},Sb:a,Bc:fb++},ua.value=c,Object.defineProperty(b,"__ext",ua),a.Pa(b))}return b}function S(b,a){var c=b.__ext;c||(R(b),c=b.__ext);return(b=c)&&b.Sb.xb(a)}function gb(b,a){for(var c=Object.getOwnPropertyNames(b),d=0,e=c.length;d<e;++d){var g=c[d];if(!(g in a)){var h=Object.getOwnPropertyDescriptor(b,
# g);try{Object.defineProperty(a,g,h)}catch(I){}}}(c=b.prototype)&&(a.prototype=c);if(b=b.name)try{Object.defineProperty(a,"name",{value:b})}catch(I){}}function hb(b){b.S.aa(function(){var a=S(this,b.m);return a?a.Ac(this):b.S.o.call(this)});b.Set.aa(function(a){var c=S(this,b.m);c?c.Set(this,a,!0,!1):b.Set.o.call(this,a);return a})}function ib(b){return b[m]||"BFRAME"===b.Type}function va(b){f.addEventListener("unload",function(){try{var a=[],a=b.Results&&(b[m]?b.Results:b.Results.filter(ib));T[m]&&
# a.push(T);var c={adbType:[b[m]?"PRESENT":"NOT"],otherData:JSON.stringify(a),clientIpAddr:"",userAgent:navigator.userAgent,pageUrl:f.location.href,detectionTime:b[J]},d={data_stream_type:"adb",json_data:JSON.stringify(c),generated_timestamp_msec:Date.now()};wa.pa.o?wa.pa.o.call(navigator,fa,JSON.stringify(d)):ab({method:"POST",url:fa,body:d,async:!0,onload:void 0,onerror:void 0,onchange:void 0})}catch(e){}},!1);return!0}function A(b,a){u(w+"."+b,a);u(U+"."+b,a)}function V(b){ga?b(ga):xa.push(b)}function jb(b){ga=
# b;var a=!0;xa.forEach(function(c){a=c(b)&&a});return a}function kb(b){if("d3d3LmNuZXQuY29t"===f.btoa(f.location.hostname)){var a=function(a){document.cookie=w+"."+ha+"="+a+";max-age=2592000;path=/;"};A(b.b.I,b.b.ac);V(function(c){if(c[m]){if(-1<document.cookie.indexOf(w+"."+ha+"="+ya)||-1==document.cookie.indexOf(w+"."+ha+"="+lb)&&.5<=Math.random())return a(ya),!0;A(b.b.I,b.b.ra)}else A(b.b.I,b.b.sa);a(f[w][b.b.I]);a(f[U][b.b.I]);return!1})}}function mb(){"d3d3Lndhc2hpbmd0b25wb3N0LmNvbQ=="===f.btoa(f.location.hostname)&&
# V(function(b){if(b[m])try{if(f.localStorage.setItem("__iabcd","true"),"true"===f.localStorage.getItem("__iabcr")||-1<document.cookie.indexOf("__iabcr=true"))return!0}catch(a){}return!1})}function B(b){return"string"===typeof b&&0<b.length?b:null}function za(b){var a="";try{a=b.location.protocol}catch(c){a="cross"}return a}function la(b,a,c){if(!b)return a;if(a)for(var d=Object.keys(a),e=d.length-1;0<=e;--e){var g=d[e],h=a[g],f=b[g],h="undefined"===typeof f?h:c(f,h);b[g]=h}return b}function W(b){return document[b]&&
# ""===document[b].name?!0:!1}var ma=function(){function b(a){this.V=this.Oa(a,[{l:/MSIE\s([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:3},{l:/Edge\/([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:5},{l:/Trident.*rv:([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:3},{l:/Chrome\/([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:1},{l:/Firefox\/([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:2},{l:/Version\/([\d]+)(\.([\d]+))?(\.([\d]+))?.*Safari/,c:4}])||{c:0,$:0,Sa:0,Ra:0};this.Xa=this.Oa(a,[{l:/Android\s([\d]+)(\.([\d]+))?(\.([\d]+))?/,c:1},{l:/CPU OS ([\d]+)(_([\d]+))?(_([\d]+))?/,
# c:2},{l:/CPU iPhone OS ([\d]+)(_([\d]+))?(_([\d]+))?/,c:2},{l:/Mac OS X ([\d]+)(_([\d]+))?(_([\d]+))?/,c:3},{l:/Windows NT ([\d]+)(.([\d]+))?(.([\d]+))?/,c:4},{l:/Linux [a-z]*([\d]+)(_([\d]+))?(_([\d]+))?/,c:5},{l:/CrOS [a-z]*([\d]+)(_([\d]+))?(_([\d]+))?/,c:5}])||{c:0,$:0,Sa:0,Ra:0}}b.prototype.Oa=function(a,b){for(var c,e=0;e<b.length;++e){var g=b[e],h=g.l.exec(a);if(null!=h){c={c:g.c,$:parseInt(h[1])||0,Sa:parseInt(h[3])||0,Ra:parseInt(h[5])||0};break}}return c};return b}(),x,t,E;"undefined"!==
# typeof navigator&&navigator.userAgent?P(navigator.userAgent):P("");Object.freeze({ua:ma,get ia(){return x},get V(){return t},get Xa(){return E},Dc:r,Jc:O,Ec:function(){return 2===t.c},Ic:function(){return 3===t.c},Hc:function(){return 5===t.c},Gc:function(){return 3===E.c},Fc:function(){return 2===E.c},Cc:P});var U=k("C61419I8"),w=k("C10117I1"),da=k("T1R9A9T7S5N6I8"),nb=k("k0c5a6b5l5l4a8C0d3b6A1r4e7t1s8i1geR"),Wa=k("T9P3I1R6C3S1B1"),Va=k("G9M2I1B6"),Xa=k("L8M9T2H0B7");k("T8N7E6M6E9L2E4");var ra=k("E1M2A7R6F1B4"),
# Q=k("E2B8U1O6Y1");k("B9U9O4Y8");k("P7B5D3A5");k("B7D4A5");k("G7D1A2");k("P8C3X3E1");var ob=k("X3L9O1V6"),ia=k("G5I7S1");k("S1T9A1T3S7G2I3S9");var pb=k("e0t6u7o3r2.7h799r005m8"),qb=k("c80511i8h2p2r5o1m6"),rb=k("0304g3/1"),ha=k("e9t2a1t4S0h6p6r4o9M4"),lb=k("d6e5k1c0o9l5b5"),ya=k("d2e5k7c1o8l4b0n8u9"),m=k("d4e1t2c9e0t6e3D6"),oa=k("n6o0s9a8e5R7"),K=k("s3t8l2u5s6e1R8"),J=k("y8c1n9e5t2a9L1n7o1i5t9c5e1t1e6D3"),Aa=k("D4E9D0A8O7L2_1V4"),Ba=k("D1E9D0A6O3L3T8O0N9_6V4"),Ca=function(){function b(){}b.prototype=
# {yc:function(a,b){a=a||this.hc();b=b||this.mode(a);return b===this.xa?this.xa(arguments.callee):b.call(this,a)},hc:function(){try{this.Pc()}catch(a){return a}},mode:function(a){return"undefined"!==typeof f&&-1<f.navigator.userAgent.indexOf("PhantomJS")?this.wc:a.arguments&&a.stack?this.chrome:a.stack&&a.sourceURL?this.zc:a.stack&&a.Oc?this.pc:a.stack&&a.fileName?this.kc:a.message&&a["opera#sourceloc"]?!a.L||-1<a.message.indexOf("\n")&&a.message.split("\n").length>a.L.split("\n").length?this.vc:this.sc:
# a.message&&a.stack&&a.L?0>a.L.indexOf("called from line")?this.tc:this.uc:a.stack&&!a.fileName?this.chrome:this.xa},chrome:function(a){return(a.stack+"\n").replace(/^[\s\S]+?\s+at\s+/," at ").replace(/^\s+(at eval )?at\s+/gm,"").replace(/^([^\(]+?)([\n$])/gm,"{anonymous}() ($1)$2").replace(/^Object.<anonymous>\s*\(([^\)]+)\)/gm,"{anonymous}() ($1)").replace(/^(.+) \((.+)\)$/gm,"$1@$2").split("\n").slice(0,-1)},zc:function(a){return a.stack.replace(/\[native code\]\n/m,"").replace(/^(?=\w+Error\:).*$\n/m,
# "").replace(/^@/gm,"{anonymous}()@").split("\n")},pc:function(a){return a.stack.replace(/^\s*at\s+(.*)$/gm,"$1").replace(/^Anonymous function\s+/gm,"{anonymous}() ").replace(/^(.+)\s+\((.+)\)$/gm,"$1@$2").split("\n").slice(1)},kc:function(a){return a.stack.replace(/(?:\n@:0)?\s+$/m,"").replace(/^(?:\((\S*)\))?@/gm,"{anonymous}($1)@").split("\n")},uc:function(a){var b=/^.*line (\d+), column (\d+)(?: in (.+))? in (\S+):$/;a=a.L.split("\n");for(var d=[],e=0,g=a.length;e<g;e+=2){var h=b.exec(a[e]);if(h){var f=
# h[4]+":"+h[1]+":"+h[2],h=h[3]||"global code",h=h.replace(/<anonymous function: (\S+)>/,"$1").replace(/<anonymous function>/,"{anonymous}");d.push(h+"@"+f+" -- "+a[e+1].replace(/^\s+/,""))}}return d},tc:function(a){var b=/^(.*)@(.+):(\d+)$/;a=a.L.split("\n");for(var d=[],e=0,g=a.length;e<g;e++){var h=b.exec(a[e]);h&&d.push((h[1]?h[1]+"()":"global code")+"@"+h[2]+":"+h[3])}return d},sc:function(a){var b=/Line (\d+).*script (?:in )?(\S+)(?:: In function (\S+))?$/i;a=a.L.split("\n");for(var d=[],e=0,
# g=a.length;e<g;e+=2){var h=b.exec(a[e]);h&&d.push((h[3]||"{anonymous}")+"()@"+h[2]+":"+h[1]+" -- "+a[e+1].replace(/^\s+/,""))}return d},vc:function(a){var b=/Line (\d+).*script (?:in )?(\S+)/i;a=a.message.split("\n");for(var d=[],e=2,g=a.length;e<g;e+=2){var h=b.exec(a[e]);h&&d.push("{anonymous}()@"+h[2]+":"+h[1]+" -- "+a[e+1].replace(/^\s+/,""))}return d},wc:function(a){var b=/(\S+) \((\S+)\)/i;a=a.stack.split("\n");for(var d=[],e=1,g=a.length;e<g;e++){a[e]=a[e].replace(/^\s+at\s+/gm,"");var h=b.exec(a[e]);
# h?d.push(h[1]+"()@"+h[2]):d.push("{anonymous}()@"+a[e])}return d},xa:function(a){for(var b=/function(?:\s+([\w$]+))?\s*\(/,d=[],e,g,h=Array.prototype.slice;a&&10>d.length;){e=b.test(a.toString())?RegExp.$1||"{anonymous}":"{anonymous}";try{g=h.call(a.arguments||[])}catch(I){g=["Cannot access arguments: "+I]}d[d.length]=e+"("+this.da(g)+")";try{a=a.caller}catch(I){d[d.length]="Cannot access caller: "+I;break}}return d},da:function(a){for(var b=[],d=Array.prototype.slice,e=0;e<a.length;++e){var g=a[e];
# void 0===g?b[e]="undefined":null===g?b[e]="null":g.constructor&&(b[e]=g.constructor===Array?3>g.length?"["+this.da(g)+"]":"["+this.da(d.call(g,0,1))+"..."+this.da(d.call(g,-1))+"]":g.constructor===Object?"#object":g.constructor===Function?"#function":g.constructor===String?'"'+g+'"':g.constructor===Number?g:"?")}return b.join(",")},Aa:{},fc:function(a){var b=this.fb();if(b)try{return b.open("GET",a,!1),b.send(null),b.responseText}catch(d){}return""},fb:function(){for(var a,b=[function(){return new XMLHttpRequest},
# function(){return new ActiveXObject("Msxml2.XMLHTTP")},function(){return new ActiveXObject("Msxml3.XMLHTTP")},function(){return new ActiveXObject("Microsoft.XMLHTTP")}],d=0;d<b.length;d++)try{return a=b[d](),this.fb=b[d],a}catch(e){}},rc:function(a){return"undefined"!==typeof location&&-1!==a.indexOf(location.hostname)},lc:function(a){a in this.Aa||(this.Aa[a]=this.fc(a).split("\n"));return this.Aa[a]},oc:function(a){for(var b=0;b<a.length;++b){var d=/^(.*?)(?::(\d+))(?::(\d+))?(?: -- .+)?$/,e=a[b],
# g=/\{anonymous\}\(.*\)@(.*)/.exec(e);if(g){var h=d.exec(g[1]);h&&(d=h[1],g=h[2],h=h[3]||0,d&&this.rc(d)&&g&&(d=this.nc(d,g,h),a[b]=e.replace("{anonymous}",d)))}}return a},nc:function(a,b){var c;try{c=this.jc(this.lc(a),b)}catch(e){c="getSource failed with url: "+a+", exception: "+e.toString()}return c},jc:function(a,b){for(var c=/function\s+([^(]*?)\s*\(([^)]*)\)/,e=/['"]?([$_A-Za-z][$_A-Za-z0-9]*)['"]?\s*[:=]\s*function\b/,g=/['"]?([$_A-Za-z][$_A-Za-z0-9]*)['"]?\s*[:=]\s*(?:eval|new Function)\b/,
# h="",f,k=Math.min(b,20),l,m=0;m<k;++m)if(f=a[b-m-1],l=f.indexOf("//"),0<=l&&(f=f.substr(0,l)),f)if(h=f+h,(f=e.exec(h))&&f[1]||(f=c.exec(h))&&f[1]||(f=g.exec(h))&&f[1])return f[1];return"(?)"}};return function(a){a=a||{mc:!0};var c=!!a.mc,d=new b;a=d.yc(a.e||null,a.mode||null);return c?d.oc(a):a}}(),na=!1,sb=function(){return function(){this.Db=[]}}(),Ra=Object.setPrototypeOf||{__proto__:[]}instanceof Array&&function(b,a){b.__proto__=a}||function(b,a){for(var c in a)a.hasOwnProperty(c)&&(b[c]=a[c])},
# X=function(){function b(a,b){this.m=a;this.j=b}b.prototype.B=function(a){this.j=a};return b}(),tb=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}l(a,b);a.prototype.B=function(a){b.prototype.B.call(this,"string"===typeof a?"true"===a:a)};return a}(X),ub=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}l(a,b);a.prototype.B=function(a){b.prototype.B.call(this,"string"===typeof a?parseInt(a):a)};return a}(X),vb=function(b){function a(){return null!==b&&
# b.apply(this,arguments)||this}l(a,b);return a}(X),Da=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}l(a,b);return a}(X),wb=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}l(a,b);return a}(Da),Ea=function(){function b(a){function c(a,b){return"undefined"!==typeof a?a:b}b.ta("ver");b.ka("rId");b.ka("iframeCommunicationTimeout",3E3);b.bc();this.Ga=b.i("enableInterception");this.qb=b.i("enableOptimizedInterceptors",!0);this.ga=b.i("enableCustomInterceptors",
# !0);this.sb=b.i("useWrapper");this.rb=b.i("partialImage");this.ob=b.i("aisao");b.ta("apiDomain");b.i("enableHtmlStreaming");b.ta("htmlStreamingVersion");b.i("enableInstantLoad");b.i("itus");b.i("rum",!1);b.ka("m_meb",0);b.i("enableMonitorData");b.i("enableProfiling");this.pb=b.i("enableHardAssert");b.ia=this;this.Ob=a;this.Pb(a);for(var d=Object.getOwnPropertyNames(a),e=d.length-1;0<=e;--e){var g=d[e],f=a[g];(g=b.Y[g])&&g.B(f)}b.Y=null;this.Fa=c(this.Fa,this.ob.j||this.rb.j);this.Ha=c(this.Ha,this.Fa);
# this.ga.B(c(this.ga.j,this.sb.j||this.Ha));this.Ga.B(c(this.Ga.j,this.qb.j||this.ga.j));na=this.pb.j}b.M=function(a){b.ia?a.B(b.ia.Ob[a.m]):(b.Y||(b.Y={}),b.Y[a.m]=a);return a};b.i=function(a,c){return b.M(new tb(a,c))};b.ka=function(a,c){b.M(new ub(a,c))};b.ta=function(a){b.M(new vb(a,void 0))};b.Kc=function(a,c){return b.M(new Da(a,c))};b.bc=function(){b.M(new wb("virtualizeDomains",void 0))};b.prototype.Qb=function(a,b){b=eval("(function(){return "+b+";})()");for(var c=Object.keys(b),e=0;e<c.length;++e){var g=
# c[e];a[g]=b[g]}};b.prototype.Rb=function(a,b){b=b.split(",");for(var c=0;c<b.length;++c){var e=b[c].split(/=|:/);2===e.length?a[e[0].trim()]=e[1].trim():console.error("invalid config value "+b[c])}};b.prototype.Pb=function(a){var b=a.devJsExtraFlags;b&&b.trim()&&("{"===b[0]?this.Qb(a,b):this.Rb(a,b),a.devJsExtraFlags="")};return b}(),D=function(b,a){return(a?Ca({e:a}):Ca()).slice(b+4)},F=F||ca(),G,ja=new sb;u(da+".Init",function(b){u(w+".CanRun",function(){return!1});u("IXC_115_9954108064986444.CanRun",
# function(){return!1});G=ca();y(!!F&&!!G,"Invalid situation");if(ja){var a=ja.Db;ja=null;b=new Ea(b);if(Ea.i("skipInit").j)console.warn("Init is skipped by skipInit flag");else for(var c=a.length,d=0;d<c;++d)a[d](b)}else console.warn("No modules initialized.");Ta()});var q;(function(b){b[b.PENDING=0]="PENDING";b[b.FULLFILLED=1]="FULLFILLED";b[b.REJECTED=2]="REJECTED"})(q||(q={}));var yb=function(){function b(a){if(!a)throw"no executor provided";if("object"!==typeof this)throw"use new";if("function"!==
# typeof a)throw"not a function";this.state=q.Ya;this.nb(a)}b.prototype.nb=function(a){var b=this;try{a(function(a){b.oa(a)},function(a){b.ab(a)})}catch(d){b.ab(d)}};b.prototype.oa=function(a){this.hb&&this.hb.call(this,a);this.state=q.Ja};b.prototype.ab=function(a){this.ya&&this.ya.call(this,a);this.state=q.$a};b.prototype.then=function(a,c){this.state===q.Ya?(this.ya=c,this.hb=a):this.state===q.Ja?a.call(this,void 0):this.state===q.$a&&c.call(this,void 0);return new b(function(){})};b.prototype.catch=
# function(a){this.state===q.Ya?this.ya=a:this.state!==q.Ja&&this.state===q.$a&&a.call(this,void 0);return new b(function(){})};b.prototype.all=function(a){var c=Array.prototype.slice.call(a);return new b(function(a,b){function d(g,f){try{if(f&&("object"===typeof f||"function"===typeof f)){var h=f.then;if("function"===typeof h){h.call(f,function(a){d(g,a)},b);return}}c[g]=f;0===--e&&a(c)}catch(xb){b(xb)}}if(0===c.length)return a([]);for(var e=c.length,f=0;f<c.length;f++)d(f,c[f])})};return b}(),L=function(){function b(){this.f=
# this.va}b.prototype.va=function(){};b.prototype.Ma=function(){return this.f!=this.va};b.prototype.W=function(a){return function(){for(var b=0,d=a.length;b<d;++b)a[b].apply(this,arguments)}};b.prototype.K=function(a){if(this.f===this.va)this.f=a;else if(this.f!==this.ec){var b=this.eb;b||(b=this.eb=[this.f,a],this.f=this.ec=this.W(b))}else this.eb.push(a);return a};return b}(),Fa=function(b){function a(){var a=b.call(this)||this;a.gb=!1;b.prototype.K.call(a,function(){});return a}l(a,b);a.prototype.W=
# function(a){return function(){if(!this.gb){for(var b=0,c=a.length;b<c;++b)a[b].apply(this,arguments);this.gb=!0}}};return a}(function(b){function a(){var a=b.call(this)||this;b.prototype.K.call(a,function(){a.Hb=this;a.Ua=arguments});return a}l(a,b);a.prototype.K=function(a){b.prototype.K.call(this,a);this.Ua&&a.apply(this.Hb,this.Ua);return a};return a}(L)),M=new Fa,N=new Fa,n;(function(b){b[b.NONE=0]="NONE";b[b.ABP=1]="ABP";b[b.AB=2]="AB";b[b.UBO=3]="UBO";b[b.UBOE=4]="UBOE";b[b.ADG=5]="ADG"})(n||
# (n={}));var v=ca(),z=f.Promise||yb,pa="&ad_box_ &ad_channel= &ad_classid= &ad_height= &ad_keyword= &ad_network_ &ad_number= &ad_type= &ad_type_ &ad_url= &ad_zones= &adbannerid= &adclient= &adcount= &adgroupid= &admeld_ &admid= &adname= &adnet= &adnum= &adpageurl= &adsafe= &adserver= &adsize= &adslot= &adslots= &adsourceid= &adspace= &adstype= &adType=PREROLL& &adunit= &adurl= &adv_keywords= &advert_ &advertiserid= &advid= &advtile= &adzone= &banner_id= &clicktag=http &customSizeAd= &displayads= &expandable_ad_ &gIncludeExternalAds= &googleadword= &jumpstartadformat= &largead= &maxads= &popunder= &program=revshare& &prvtof=*&poru= &show_ad_ &showad= &simple_ad_ &smallad= &smart_ad_ &strategy=adsense& &type=ad& &UrlAdParam= &video_ads_ &videoadid= &view=ad&".split(" "),
# H="aHR0cHM6Ly9wYWdlYWQyLmdvb2dsZXN5bmRpY2F0aW9uLmNvbS9mYXZpY29uLmljbw== aHR0cHM6Ly9zMC4ybWRuLm5ldC8xNjM1OTA5LzF4MWltYWdlLmpwZw== aHR0cHM6Ly93d3cueWFob28uY29tL3B4LmdpZg== aHR0cHM6Ly9jb25uZWN0LmZhY2Vib29rLm5ldC9mYXZpY29uLmljbw== aHR0cHM6Ly9hZHMudHdpdHRlci5jb20vZmF2aWNvbi5pY28= aHR0cHM6Ly93d3cuZ29vZ2xlLWFuYWx5dGljcy5jb20vX191dG0uZ2lm aHR0cHM6Ly90cGMuZ29vZ2xlc3luZGljYXRpb24uY29tL2Zhdmljb24uaWNv aHR0cHM6Ly9zZWN1cmUuZm9vdHByaW50Lm5ldC95aWVsZG1hbmFnZXIvYXBleC9tZWRpYXN0b3JlL2FkY2hvaWNlXzEucG5n".split(" "),
# sa="undefined"!==typeof performance&&performance.now&&function(){return performance.now()}||Date&&Date.now&&function(){return Date.now()},Ga="aHR0cHM6Ly85NTczMjgtaGIuYWRvbWlrLmNvbS9haGJhLmpz aHR0cHM6Ly9hZC5hZGlwLmx5L2RsdnIvYWRpcGx5X3N0YXRtYXJnLm1pbi5qcw== aHR0cHM6Ly9hZC5hZnkxMS5uZXQvY2RzYWQuanM= aHR0cHM6Ly9hZC50dXJuLmNvbS9zZXJ2ZXIvYWRzLmpz aHR0cHM6Ly9hZHMuY29udGV4dHdlYi5jb20vVGFnUHVibGlzaC9HZXRBZC5hc3B4 aHR0cHM6Ly9ha2ZzLm5zcG1vdGlvbi5jb20vYWVwL3RhZy9hci9hcl9tc25fMTI3MHgzNDhfdml0cmluZS5jZmcuanM= aHR0cHM6Ly9ha2ZzLm5zcG1vdGlvbi5jb20vYWVwL3RhZy9ici9icl9tc25faG9tZV92aXRyaW5lLmpz aHR0cHM6Ly9jLmdyZXlzdHJpcGUuY29tL2dzc3dmL2FkLmpz aHR0cHM6Ly9jZG4tYWthbWFpLm1vb2tpZTEuY29tL2h0bWwvdHJiX2l0cnNfc2Vnc19zeW5jLmpz aHR0cHM6Ly9jZG4uYWRueHMuY29tL21zZnQvQ29udGFpbmVyVGFnLXY5Lmpz aHR0cHM6Ly9jZG4ubm1jZG4udXMvanMvY29ubmVjdC5qcw== aHR0cHM6Ly9jZG4ucmV2Y29udGVudC5jb20vYnVpbGQvanMvcmV2Mi5taW4uanM= aHR0cHM6Ly9jZG4uc3ByaW5nc2VydmUuY29tL3ZkL3ZkLTAuMi43MC1iZXRhLjIuanM= aHR0cHM6Ly9kYXRhMDEuYWRsb294dHJhY2tpbmcuY29tL2Fkcy9pYy5waHA= aHR0cHM6Ly9kYXRhNTYuYWRsb294dHJhY2tpbmcuY29tL2Fkcy9pYy5waHA= aHR0cHM6Ly9kYXRhbTA3LmFkbG9veHRyYWNraW5nLmNvbS9hZHMvaWMucGhw aHR0cHM6Ly9oYWw5MDAwMjEucmVkaW50ZWxsaWdlbmNlLm5ldC9yZXF1ZXN0LnBocA== aHR0cHM6Ly9oYi5zZWtpbmRvLmNvbS9saXZlL2xpdmVWaWV3LnBocA== aHR0cHM6Ly9ob3Jpem9uLmJ0cmxsLmNvbS93ZjkwLTUxMjU5My9ob3Jpem9uLmpz".split(" "),
# Ha="aHR0cHM6Ly9pbWFzZGsuZ29vZ2xlYXBpcy5jb20vanMvc2RrbG9hZGVyL2ltYTMuanM= aHR0cHM6Ly91cy11Lm9wZW54Lm5ldC93LzEuMC9zZA== aHR0cHM6Ly9wYWdlYWQyLmdvb2dsZXN5bmRpY2F0aW9uLmNvbS9wYWdlYWQvanMvZ29vZ2xlX3RvcF9leHAuanM= aHR0cHM6Ly9zZWN1cmUuYWRueHMuY29tL3R0ag== aHR0cHM6Ly9iaC5jb250ZXh0d2ViLmNvbS9iaC9ydHNldA== aHR0cHM6Ly9hZHMucnViaWNvbnByb2plY3QuY29tL2hlYWRlci8xMTg3Mi5qcw== aHR0cHM6Ly9hYXguYW1hem9uLWFkc3lzdGVtLmNvbS9lL2R0Yi9iaWQ= aHR0cHM6Ly9qcy5yZXZzY2kubmV0L2dhdGV3YXkvZ3cuanM= aHR0cHM6Ly93d3cuemVyZ25ldC5jb20vb3V0cHV0Lmpz aHR0cHM6Ly9uYXRpdmUuc2hhcmV0aHJvdWdoLmNvbS9hc3NldHMvc2ZwLmpz aHR0cHM6Ly9hZHMucnViaWNvbnByb2plY3QuY29tL2hlYWRlci84NjY3Lmpz aHR0cHM6Ly9nMi5ndW1ndW0uY29tL2phdmFzY3JpcHRzL2dndjIuanM= aHR0cHM6Ly93d3cuaW5zdGljYXRvci5jb20vdmFzc2V0cy9qYXZhc2NyaXB0cy9zZXJ2aWNlL2luc3RpY2F0b3ItaGItdjE1Lmpz".split(" "),
# ta=[["iframe","google_ads_frame"],["iframe","google_ads_iframe"],["div","ADV-SLOT-"],["div","YFBMSN"],["div","google_dfp_"],["div","MarketGid"]],zb=function(){function b(a){this.ja=0;this.g=a;this.dc=$a();Ya();this.Ta=this.zb()}b.prototype.zb=function(){for(var a=[],b=0;b<this.g.b.Kb;b++)a.push(qa("script",Ga));for(b=0;b<this.g.b.Ib;b++)a.push(qa("",Ha));for(b=0;b<this.g.b.Lb;b++)a.push(Za());for(b=0;b<this.g.b.Jb;b++)a.push(Ua());this.ja=a.length;return a};b.prototype.mb=function(a){M.K(function(b,
# c){b=!1;c!==n.NONE&&(b=!0);a(p(ia,b))});if(this.g.b.Ea)z.all(this.Ta).then(a);else for(var b=0;b<this.ja;b++)this.Ta[b].then(a)};return b}();[H,Ha,[],Ga].forEach(function(b){return b.forEach(function(a,b,d){return d[b]=f.atob(a)})});var ea=function(){function b(a){this.wa=a}b.prototype.J=function(){return 1223===this.wa.status?204:this.wa.status};b.prototype.Error=function(){return 100>this.J()||599<this.J()?"Network request failed":null};b.prototype.Text=function(){return this.wa.responseText};return b}(),
# bb={lb:XMLHttpRequest,Nb:XMLHttpRequest.prototype.open,Vb:XMLHttpRequest.prototype.send},Ia=function(){function b(a){this.Za=a;this.Ia=Object.create(a&&a.Ia);this.jb=this.Ka=null;this.Wa=new L;this.Va=new L}b.prototype.xb=function(a){return this.Ia[a]};b.prototype.ub=function(a,b){for(var c;a&&!c;){if(c=Object.getOwnPropertyDescriptor(a,b))c.kb=a;a=Object.getPrototypeOf(a)}return c};b.prototype.Ab=function(a,b){var c=b.m;if((a=this.ub(a,c))&&a.value)return b.Yb(a.value),a.kb[c]=b.F,b.J=a.writable?
# 1:5,a.writable;b.J=3;return!1};b.prototype.Bb=function(a,b){if(b){for(var c=[],e=b.length-1;0<=e;--e){var g=b[e];2===g.J||this.Ab(a,g)||3===g.J||c.push(g)}c.length&&(this.Ka=c)}};b.prototype.Pa=function(a){this.Wa&&this.Wa.f(a);var b=this.Ka;if(b)for(var d=b.length-1;0<=d;--d){var e=b[d],g={value:e.F,configurable:!0,enumerable:!0};try{Object.defineProperty(a,e.m,g)}catch(h){}}if(b=this.jb)for(d=b.length-1;0<=d;--d){e=b[d];g={get:e.S.F,set:e.Set.F,configurable:!0,enumerable:!0};try{Object.defineProperty(a,
# e.m,g)}catch(h){}}this.Va&&this.Va.f(a);this.Za&&this.Za.Pa(a)};return b}(),eb=[],db={},fb=0,cb=Object.prototype.hasOwnProperty,ua={enumerable:!1,writable:!1},Ja=function(){return function(b){this.m=b;this.J=0}}();(function(b){function a(){return null!==b&&b.apply(this,arguments)||this}l(a,b);a.prototype.W=function(a){return function(){for(var b=!1,c=0,g=a.length;c<g;++c)b=a[c].apply(this,arguments)||b;return b}};return a})(L);(function(b){function a(){return null!==b&&b.apply(this,arguments)||this}
# l(a,b);a.prototype.W=function(a){return function(b){for(var c=0,d=a.length;c<d;++c)b=a[c].apply(this,arguments)||b;return b}};return a})(L);var Y=function(b){function a(a,d){void 0===d&&(d=!1);var c=b.call(this,a)||this;c.F=d?function(){return R(c.ha.apply(this,arguments))}:function(){return c.ha.apply(this,arguments)};return c}l(a,b);a.prototype.cb=function(){var a=this.U&&this.U.Ma(),b=this.T&&this.T.Ma(),a=this.O?a?b?7:5:b?6:4:a?b?3:1:b?2:0,b=this.Z&&this.Z[a];if(!b){var e=this;switch(a){case 0:b=
# this.o;break;case 1:b=function(){var a;e.U.f.apply(this,arguments)||(a=e.o.apply(this,arguments));return a};break;case 2:b=function(){var a=e.o.apply(this,arguments);return a=e.T.f.call(this,a)||a};break;case 3:b=function(){var a;e.U.f.apply(this,arguments)||(a=e.o.apply(this,arguments),a=e.T.f.call(this,a)||a);return a};break;case 4:b=this.O;break;case 5:b=function(){var a;e.U.f.apply(this,arguments)||(a=e.O.apply(this,arguments));return a};break;case 6:b=function(){var a=e.O.apply(this,arguments);
# return a=e.T.f.call(this,a)||a};break;case 7:b=function(){var a;e.U.f.apply(this,arguments)||(a=e.O.apply(this,arguments),a=e.T.f.call(this,a)||a);return a}}0!=a&&4!=a&&(this.Z||(this.Z=[]),this.Z[a]=b)}this.__=this.ha=b};a.prototype.Yb=function(a){this.o=a;gb(a,this.F);this.F.toString=function(){return a.toString()};this.cb()};a.prototype.aa=function(a){this.O=a;this.cb()};return a}(Ja);(function(b){function a(a){var c=b.call(this,a,!0)||this;c.F=function(){var a;a=c.ha;switch(arguments.length){case 0:a=
# new a;break;case 1:a=new a(arguments[0]);break;case 2:a=new a(arguments[0],arguments[1]);break;case 3:a=new a(arguments[0],arguments[1],arguments[2]);break;case 4:a=new a(arguments[0],arguments[1],arguments[2],arguments[3]);break;default:throw"Unsupported case!";}return R(a)};return c}l(a,b);return a})(Y);(function(b){function a(a){var c=b.call(this,a,!1)||this;c.S.aa(function(){var a=S(this,c.m);return a&&(a=a.La(this))?a.Lc:c.S.o.apply(this,arguments)});c.Set.aa(function(a){var b=S(this,c.m);return b?
# (b.La(this)||(b.La(this,!0,a),c.Set.o.call(this,null)),b.Set(this,a,!0,!1),a):c.Set.o.apply(this,arguments)});return c}l(a,b);return a})(function(b){function a(a,d,e){void 0===d&&(d=!1);var c=b.call(this,a)||this;c.S=new Y(a,d);c.Set=new Y(a,d);e&&hb(c);return c}l(a,b);return a}(Ja));var Ab=new (function(b){function a(){return b.call(this,null)||this}l(a,b);return a}(Ia)),wa=new (function(b){function a(){var a=b.call(this,Ab)||this;a.pa=new Y("sendBeacon");var d=Object.getPrototypeOf(navigator);d.__pext=
# a;a.Bb(d,[a.pa]);return a}l(a,b);return a}(Ia)),T=p(ob,!1);f.addEventListener("message",function(b){b=b.data;"string"!==typeof b||0!==b.lastIndexOf(Aa,Aa.length+1)&&0!==b.lastIndexOf(Ba,Ba.length+1)||(T[m]=!0,T[oa]=b)});var xa=[],ga;A(nb,V);!f[w]&&u(w,{});!f[U]&&u(U,{});var fa,Bb=function(){function b(a){this.h={};this.ea=Date.now();this.P=!1;this.g=a;this.fa=new zb(a);this.h[K]=[];this.h[J]=0;this.h[m]=!1;fa=a.b.Ba;V(va)}b.prototype.ma=function(){var a=this;this.fa.dc.then(function(b){var c=!0;try{A(a.g.b.I,
# a.P?a.g.b.ra:a.g.b.sa);A(a.g.b.Eb,a.h.DetectionLatency);a.h[K].push(b);var e=jb(a.h);!b[m]&&a.P&&e&&a.g.b.C&&a.na();c=!1}catch(g){a.h[K].push(void 0),va(a.h),a.g.b.C&&a.na(),c=!1}finally{c&&a.g.b.C&&a.na()}})};b.prototype.ib=function(){var a=this,b=0,d=!1,e=!1,f=this.fa.ja;this.fa.mb(this.g.b.Ea?function(c){if(!e){a.h[J]=Date.now()-a.ea;for(var d=0;d<c.length;d++)c[d][m]&&b++,b>=a.g.b.X&&(a.P=!0,a.h[m]=!0);e=!0;a.ma()}}:function(c){a.h[K].push(c);var g=a.h.Results.length;c[m]&&b++;c.Type===ia&&(d=
# !0);e||(c.Type===ia&&c[m]||b>=a.g.b.X?(e=!0,a.h[J]=Date.now()-a.ea,a.h[m]=!0,a.P=!0,a.ma()):f-g<a.g.b.X&&d&&(e=!0,a.h[J]=Date.now()-a.ea,a.P=!1,a.h[m]=!1,N.K(function(b,c){c!==n.NONE&&a.h[K].push(void 0)}),a.ma()))})};b.prototype.na=function(){document.cookie=pb+"="+Date.now()+";max-age=86400";document.cookie=qb+"=1;max-age=86400";var a=f.location,b=rb;a.pathname&&("/"!==a.pathname[0]&&(b+="/"),b+=a.pathname);var d="i10c.referrer="+encodeURIComponent(document.referrer);a.search?(b+=a.search,b+="&"+
# d):b+="?"+d;a.hash&&(b+=a.hash);f.location.href=b;document.close()};return b}(),Cb=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}l(a,b);return a}(function(){return function(){}}()),Db=/^(?:([^:/?#]+):)?(?:\/\/(?:([^/?#]*)@)?([^/?#:@]*)(?::([0-9]+))?)?([^?#]+)?(?:\?([^#]*))?(?:#(.*))?$/,Ka=/[#\/\?@]/g,Eb=/[#\/\?]/g,Fb=/[#\?]/g,Gb=/[#]/g,Hb=/(\/|^)(?:[^./][^/]*|\.{2,}(?:[^./][^/]*)|\.{3,}[^/]*)\/\.\.(?:\/|$)/,La=/^(?:\.\.\/)*(?:\.\.$)?/,Z=function(){function b(a){if(a){if("string"===
# typeof a)if(a=(""+a).match(Db)){var b=a[7];a={v:B(a[1]),N:B(a[2]),s:B(a[3]),Port:B(a[4]),G:B(a[5]),H:B(a[6]),R:"string"===typeof b?b:null}}else a=null}else a={v:null,N:null,s:null,Port:null,G:null,H:null,R:null};this.a=a;this.Cache={D:null,la:null,Na:null,Ub:null,cc:null,Tb:null}}b.prototype.Qa=function(){return!!this.a.v&&!!this.a.s};b.prototype.Cb=function(){var a=this.a.v;return a&&("http"===a||"https"===a||"ftp"===a)};b.prototype.qa=function(a){if(Ka.test(a))return this;this.a.v=a?a.toLowerCase():
# null;a=this.Cache;a.D=null;a.la=null;return this};b.prototype.wb=function(){var a=this.a.v;return a&&a+":"};b.prototype.Wb=function(a){Ka.test(a)||(this.a.N=a,this.Cache.D=null)};b.prototype.ba=function(a){if(Eb.test(a))return this;this.a.s=a;a=this.Cache;a.D=null;a.la=null;a.Na=null;a.Ub=null;a.cc=null;return this};b.prototype.bb=function(a){if(a){a=Number(a);if(a!==(a&65535))return;this.a.Port=""+a}else this.a.Port=null;a=this.Cache;a.D=null;a.la=null;a.Na=null};b.prototype.vb=function(){var a=
# "",b=this.a.G;b&&(a+=b);(b=this.a.H)&&(a+="?"+b);(b=this.a.R)&&(a+="#"+b);return""!==a?a:null};b.prototype.Zb=function(a){if(a){if(Fb.test(a))return;this.a.G=!this.a.s||/^\//.test(a)?a:"/"+a}else this.a.G=null;this.Cache.D=null};b.prototype.$b=function(a){Gb.test(a)||(this.a.H=a,a=this.Cache,a.D=null,a.Tb=null)};b.prototype.Xb=function(a){this.a.R=a;this.Cache.D=null};b.Gb=function(a){return a.replace(/(^|\/)\.(?:\/|$)/g,"$1").replace(/\/{2,}/g,"/")};b.Ca=function(a){if(null===a)return null;a=this.Gb(a);
# for(var b;(b=a.replace(Hb,"$1"))!=a;a=b);return a};b.oa=function(a,c){var d=new b;a=a instanceof b?a:new b(a);c=c instanceof b?c:new b(c);var e=!!c.a.v;d.qa(e?c.a.v:a.a.v);e=e||!!c.a.N;d.Wb(e?c.a.N:a.a.N);e=e||!!c.a.s;d.ba(e?c.a.s:a.a.s);e=e||!!c.a.Port;d.bb(e?c.a.Port:a.a.Port);var e=e||!!c.a.G,f,h=c.a.G,k=a.a.G,l=d.Cb()||!d.a.v;e?(f=h,l&&h&&"/"!==h[0]&&k&&(f=k.lastIndexOf("/")+1,f=(f?k.substring(0,f):"")+h)):f=k;l&&f&&(f="/"===f[0]?"/"+b.Ca(f).substring(1).replace(La,""):b.Ca(f).replace(La,""));
# d.Zb(f);e=e||!!c.a.H;d.$b(e?c.a.H:a.a.H);e=e||!!c.a.R;d.Xb(e?c.a.R:a.a.H);return d};return b}();(function(b){function a(c,d){c instanceof Z&&c.Qa()||(c=a.oa(d,c),y(c.Qa(),"Attempted to create a non-absolute url",!1));return b.call(this,c.a)||this}l(a,b);a.prototype.qa=function(a){y(!!a,"Cannot assign an empty or null scheme to an absolute uri",!1);return b.prototype.qa.call(this,a)};a.prototype.ba=function(a){y(!!a,"Cannot assign an empty or null domain to an absolute uri",!1);return b.prototype.ba.call(this,
# a)};return a})(Z);var Ma=function(b){function a(a){if(!a){a=void 0;try{a=document.cookie}catch(g){a=""}var c;c=f;for(var e=za(c);"http:"!==e&&"https:"!==e&&"cross"!==e&&c!=c.parent;)c=c.parent,e=za(c);c=c.location;a={url:c.href,headers:{host:c.host,cookie:a}}}return b.call(this,a)||this}l(a,b);return a}(function(){function b(a,b){this.u=a;this.A=b;this.u=this.u||{};this.u.headers=this.u.headers||{};this.ua=this.u.headers["user-agent"]?P(this.u.headers["user-agent"]):x;this.A||(this.A=new Z(this.u.url));
# this.A.a.s||(a=new Z("//"+this.u.headers.host),this.A.ba(a.a.s),this.A.bb(a.a.Port))}b.prototype.tb=function(){return this.u.headers.host};b.prototype.Fb=function(a,b){return a.$>=b&&1E3>=a.$};b.prototype.host=function(a){return this.tb()===a};b.prototype.domain=function(a){return this.A.a.s===a};b.prototype.ca=function(a){return a.test(this.A.vb())};b.prototype.protocol=function(a){return this.A.wb().toLowerCase()===a.toLowerCase()};b.prototype.gc=function(a){return a.test(this.u.headers.cookie)};
# b.prototype.cookie=function(a,b){return this.gc(new RegExp(a+"s*=[^;]*"+b+"[^;]*"))};b.prototype.w=function(a,b){switch(a){case "ie":a=3;break;case "chrome":a=1;break;case "edge":a=5;break;case "firefox":a=2;break;case "safari":a=4;break;default:a=0}return this.ua.V.c==a&&this.Fb(this.ua.V,b?b:Number.MIN_VALUE)};return b}()),Ib=function(b){function a(){return null!==b&&b.apply(this,arguments)||this}l(a,b);a.prototype.b=function(a){return this.j.b=la(this.j.b,a,C)};return a}(function(){return function(b){this.j=
# b}}()),Na,ka=function(b,a){new Cb(b.ic);var c=new Ma(b.xc);new Ma(b.qc);b=new Ib(a);c.w("chrome",46)&&b.b({C:!0});(c.w("chrome",46)||c.w("firefox",38)||c.w("safari",10)||c.w("ie",10)&&document&&10>document.documentMode||c.w("edge",12))&&b.b({Da:!0});b.b({I:"MorphState",ra:"blocked",sa:"not-blocked",Eb:"Abdt",Kb:4,Mb:0,Ib:4,Lb:4,Jb:4,X:3,Ea:!1,Ba:"/g00/2_d3d3LmJvc3Rvbi5jb20%3D_/TU9SRVBIRVVTOCRodHRwOi8vY3AtaW4ubmFub3Zpc29yLmlvL2NsaWVudHByb2ZpbGVyL2FkYj9pMTBjLm1hcmsuc2NyaXB0LnR5cGU%3D_$/$/$"});c.host(f.atob("d3d3LmNuZXQuY29t"))&&
# b.b({ac:"detecting"});c.host(f.atob("d3d3LmZvY3VzLmRl"))&&b.b({Mb:4});(c.host(f.atob("d3d3Lm1zbi5jb20="))||c.host(f.atob("aW50MS5tc24uY29t")))&&b.b({I:"Abd",ra:1,sa:0,X:4,Ba:"//tu9srvbirvvtocrjcc1pbi5uyw5vdmlzb3iuaw80.g00.msn.com/g00/2_d3d3Lm1zbi5jb20%3D_/TU9SRVBIRVVTOCRodHRwOi8vY3AtaW4ubmFub3Zpc29yLmlvL2NsaWVudHByb2ZpbGVyL2FkYj9pMTBjLm1hcmsuc2NyaXB0LnR5cGU%3D_$/$/$"}).C&&f&&1===f["ad-instart2"]&&b.b({C:!1});c.host(f.atob("d3d3Lm1zbi5jb20="))&&(c.ca(/\/(?:en-ca\/?(?:[?#]|$))/i)||c.ca(/\/(?:en-ca\/(?:autos|news|money|sports|travel|health|lifestyle|entertainment|foodanddrink|weather|video))/i)||
# c.ca(/\/(?:fr-ca\/?(?:[?#]|$))/i)||c.ca(/\/(?:fr-ca\/(?:finances|voyage|actualites|sports|style-de-vie|divertissement|cuisine-et-vins|meteo|video))/i))&&c.w("safari",10)&&b.b({C:!0});c.host(f.atob("aW50MS5tc24uY29t"))&&c.w("safari",10)&&b.b({C:!0});(c.host(f.atob("d2VhdGhlci5jb20="))||c.host(f.atob("c3RhZ2Uud2VhdGhlci5jb20=")))&&!c.w("chrome",46)&&b.b({Da:!1});return b.j}({ic:{},qc:Na={url:f.location.href,headers:{host:f.location.host,cookie:document.cookie}},xc:Na},{}),Oa=function(){var b=n.NONE,
# a=Object.getOwnPropertyDescriptor(Element.prototype,f.atob("c2hhZG93Um9vdA=="));(a&&a[f.atob("Z2V0")]&&a[f.atob("Z2V0")].name)===f.atob("Z2V0")&&(b=n.AB);return b}();if(r()){var aa=document.createElement("link"),Pa=!1;aa.rel="preload";aa.addEventListener("error",function(){Pa=!0});Oa!==n.NONE&&W("createElement")&&W("createRange")?(f.setTimeout(function(){Pa?M.f("PatchedAddEventListener",n.NONE):M.f("PatchedAddEventListener",n.AB)},500),document.head.appendChild(aa),aa.href=Math.random().toString(36).substr(2,
# 5)+"://"):M.f("PatchedAddEventListener",n.NONE)}else M.f("PatchedAddEventListener",n.NONE);if(r()){var ba=document.createElement("link");ba.rel="preload";var Qa=!1;ba.onerror=function(){Qa=!0};Oa!==n.NONE&&W("createElement")&&W("createRange")?(f.setTimeout(function(){Qa?N.f("PatchedOnError",n.NONE):N.f("PatchedOnError",n.AB)},500),document.head.appendChild(ba),ba.href=Math.random().toString(36).substr(2,5)+"://"):N.f("PatchedOnError",n.NONE)}else N.f("PatchedOnError",n.NONE);if(f===top&&ka.b.Da){var Jb=
# new Bb(ka);kb(ka);mb();Jb.ib()}}(this.yb=this.yb||{})})(window);
# }
# })();
# </script>
# <!-- includes\2-column-quotes-300-right.master -->
# <meta charset="utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge;chrome=1" />
# <meta name="viewport" content="width=device-width" />
#
#
# <!-- START page level head content -->
# <title>AMZN stock quote - Amazon.com, Inc. Common Stock price - NASDAQ.com</title>
# <!-- aspx\SummaryQuote.aspx -->
# <meta name="description" content="Stock&#32;quote&#32;for&#32;Amazon.com,&#32;Inc.&#32;Common&#32;Stock&#32;(AMZN)&#32;-&#32;Get&#32;real-time&#32;last&#32;sale&#32;and&#32;extended&#32;hours&#32;stock&#32;prices,&#32;company&#32;news,&#32;charts,&#32;and&#32;company-specific&#32;research&#32;tools&#32;for&#32;Amazon.com,&#32;Inc.&#32;Common&#32;Stock&#32;(AMZN)&#32;at&#32;NASDAQ.com" />
# <meta name="robots" content="index,follow">
# <link rel="canonical" href="http://www.nasdaq.com/symbol/amzn" />
# <link rel="alternate" media="only screen and (max-width: 640px)" href="http://m.nasdaq.com/symbol/amzn" >
# <link rel="alternate" href="http://www.nasdaq.com/es/symbol/amzn" hreflang="es-es" />
# <link rel="alternate" href="http://www.nasdaq.com/it/symbol/amzn" hreflang="it-it" />
# <link rel="alternate" href="http://www.nasdaq.com/de/symbol/amzn" hreflang="de-de" />
# <link rel="alternate" href="http://www.nasdaq.com/zh/symbol/amzn" hreflang="zh-cn" />
# <link rel="alternate" href="http://www.nasdaq.com/fr/symbol/amzn" hreflang="fr-fr" />
# <link rel="alternate" href="http://www.nasdaq.com/symbol/amzn" hreflang="x-default" />
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta property="og:title" content="Amazon.com,&#32;Inc.&#32;Common&#32;Stock (AMZN)" />
# <meta property="og:type" content="website" />
# <meta property="og:site_name" content="NASDAQ.com" />
# <meta property="og:url" content="http://www.nasdaq.com/symbol/amzn" />
# <meta property="og:image" content="http://www.nasdaq.com/logos/fb/AMZN.gif" />
#
#
# <script type="text/javascript">
# var myPage = 'summaryquote';//page var
# sectionId = 'liQuotes';//section tab
# breadCrumbId = 'qQuotes';//page
# is_dartSite = "quotes";
# is_dartZone = "sq";
# var propVar = "SummaryQuotes";	//omniture var
# var propVar15 = "Quotes";
# googlechannel = 'Quotes,Summaryquote';
# googlehints = 'stock market, stock investment, trading account, real time quotes, portfolio tracking, stock charts, options trading, Nasdaq Stocks, Nasdaq Companies, Company Profiles, stock research, shares outstanding, stock Dividends, Stock trading, online stock, stock price, stock symbol, common stock, stock analysis, Options Trading, stock information';
#
# /*
# SRA ad definitions, this should always correspond with the ad calls on the page
# if an ad is removed from the page, it should be removed from here as well
# */
#
# var useSRA = true;
# var premakeAds = [];
#
# /*quote page ads*/
# premakeAds.push({'label':'condition', 'expression':!/selectedsymboltype=[^(%2c)]*(%2c)*(Mutual%20Fund|Money%20Market|Index)/.test(document.cookie),
# 	'true':{'label':'ad', 'size':'120x60','site': 'box_button','zone': is_dartZone}//quotebox ad, hide for certain market types
# });
# premakeAds.push({'label':'ad', 'size':'120x60','site':'leftnav_top','zone':is_dartZone});//quote navigation ad
# premakeAds.push({'label':'ad', 'size': '980x20','site': is_dartSite,'zone': is_dartZone});//ICU ad
# /*page-level custom ads */
#
# //right side ads
# premakeAds.push({ 'label': 'ad', 'size': '300x250,300x600', 'site': is_dartSite, 'zone': is_dartZone });
# //premakeAds.push({ 'label': 'ad', 'size': '120x60', 'site': 'newsbox', 'zone': is_dartZone });
# premakeAds.push({ 'label': 'ad', 'size': '300x250,300x600,285x100', 'site': 'mop', 'zone': is_dartZone });//right side dianomi
# premakeAds.push({ 'label': 'ad', 'size': '300x250,300x600,160x600', 'site': 'btf', 'zone': is_dartZone });
#
# </script>
# <!-- END page level head content -->
#
#
# <!--********************************* BEGIN includes/global-references.inc **************************-->
# <!-- global stylesheets -->
# <link rel="stylesheet" type="text/css" href="http://www.nasdaq.com/includes/global.min-04252017v2.css" />
# <!--[if lt IE 9]>
# <script src="http://www.nasdaq.com/includes/html5shiv-printshiv.js"></script>
# <link rel="stylesheet" type="text/css" href="http://www.nasdaq.com/includes/global-ie8.min-11212015v1.css" />
# <![endif]-->
#
# <!-- favicon and shortcut icons -->
# <link rel="apple-touch-icon" href="http://www.nasdaq.com/images/Q_apple.png"/>
# <link rel="shortcut icon" href="http://www.nasdaq.com/images/qfav.ico" type="image/ico" />
# <link rel="icon" href="http://www.nasdaq.com/images/qfav.ico" type="image/x-icon"/>
# <link rel="shortcut icon" href="http://www.nasdaq.com/images/qfav.ico" type="image/x-icon"/>
# <link rel="stylesheet" href="http://cdn.ideamelt.com/1.6/css/ideamelt.min.css">
# <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" />
#
# <!-- scripts -->
#
# <!-- district M -->
# <script type="text/javascript" src="//hi.districtm.ca/v3.0.103185.js"></script>
# <script type="text/javascript" src="//hi.districtm.ca/currency.js"></script>
# <script type="text/javascript" src="//cdn.districtm.ca/v4.0.header.min.js"></script>
#
# <!-- OpenX -->
# <script type="text/javascript" src="//ox-d.nasdaq.servedbyopenx.com/w/1.0/jstag?nc=3244-NASDAQ"></script>
#
# <!-- Casale -->
# <script>window.Headertag_defer_queue = [];</script>
# <script src="http://js.indexww.com/ht/headertag-nasdaq.js"></script>
#
# <!-- GPT -->
# <script async="true" src="http://www.googletagservices.com/tag/js/gpt.js"></script>
#
# <script src="http://www.nasdaq.com/dynamic_includes/marketstatus.js"></script>
# <script src="http://www.nasdaq.com/aspx/marketstatus.aspx"></script>
#
# <script src="http://www.nasdaq.com/includes/jquery.min.js"></script>
# <script src="http://www.nasdaq.com/includes/global.min-04042017v1.js"></script>
#
# <!-- the dynamic css container -->
# <style type="text/css" title="dynamic"></style>
# <script type="text/javascript">
# //<![CDATA[
# updateSiteTheme();
# nasdaqIndexRow.init("NasdaqDjiaspx");
# //]]>
# </script>
# <script type='text/javascript' src='//rndntpmgnj-a.akamaihd.net/NA2L50A6M.js' async></script>
#
# <!-- Begin Dynamic Yield -->
# <script type="text/javascript" src="//cdn.dynamicyield.com/api/8767356/api_dynamic.js"></script>
# <script type="text/javascript" src="//cdn.dynamicyield.com/api/8767356/api_static.js"></script>
# <!-- End Dynamic Yield -->
#
# <!--********************************* END includes/global-references.inc **************************-->
#
# <!-- Begin includes/head-quotes-content.inc -->
# <link rel="stylesheet" type="text/css" href="http://www.nasdaq.com/includes/quotenav-with-quotebar.min-07072016v2.css" />
# <script type="text/javascript" src="http://www.nasdaq.com/includes/global-quotes.min-03292017v1.js"></script>
#
# <!-- End includes/head-quotes-content.inc -->
#
# <script type="text/javascript">
#     var server_time = new Date(1493384072813);
# </script>
#
#
# <!-- START page level style/script -->
#
# <script type="text/javascript">
# <!--
#
# var mobileModule = createMobileModule("mobileSummaryaccess",window.location.href.replace("http://www", "http://m"));
# mobileModule.checkFullSiteAccess();
#
# var intlModule = createLocalityModule("intlAccess",window.location.href.replace("nasdaq.com", "nasdaq.com/{0}"), 30, 733);
# intlModule.checkUSSiteAccess();
#
# //refresh the page, track the event in omniture
# function refresh() {
#     triggerAsyncOmnitureClickEvent('quotes:refresh:summaryquote');
#     window.location.reload();
# }
#
# addIMAppLoadFunction(function () {
#
#     melt.initApp($("#SQFlyNextBox"), 'melt-fly-next-stocks', {
#         'symbol': 'AMZN',
#         'element': 'left-column-div'
#     });
#
# });
#
# //ad refresh
# autoAdRefresh([4,8,11], 125000);
#
# //-->
# </script>
# <style type="text/css">
# .iq_buttons table td {
#     padding-right: 10px
# }
# .iq_buttons td a {
#     font-size: 11px;
#     display: block;
#     float: left;
#     margin-left: 5px
# }
# </style>
# <!-- END page level style/script -->
#
#
# <style type="text/css">
# #container.wrap {
#     background-color: #ffffff
# }
# #panel_left, .qbreadcrumb {
#     float: left;
# }
# div#right-column-div {
#     float: right;
#     margin-right: 10px;
#     margin-top: 10px;
#     width: 300px;
# }
# div#left-column-div {
#     margin: 10px 15px;
#     padding-right: 15px;
#     width: 495px;
# }
# </style>
# </head>
#
# <body id="body">
# <script src="http://www.nasdaq.com/includes/advertisement.js"></script>
# <script type="text/javascript">checkABDetected();</script>
#
# <!--[if IE 8]> <script src="http://www.nasdaq.com/includes/respond.js"></script> <![endif]-->
# <!--[if IE 7]> <script src="http://www.nasdaq.com/includes/zindex.js"></script> <![endif]-->
#
#
#
#     <!--*************************************** BEGIN includes/global-masthead.inc ****************************************-->
#
# <header id="global_header" data-role="header">
# 	<!--// Begin Hot Topics -->
#     <div id="hot_topics">
#         <div><span>Hot Topics:</span></div>
#         <a href="http://www.nasdaq.com/etfs" onclick="triggerAsyncOmnitureClickEvent('nav:hot-topics:ETFs')">ETFs</a> <span>|</span>
#         <a href="https://stocktracker.nasdaq.com/smart-portfolio/welcome" onclick="triggerAsyncOmnitureClickEvent('nav:hot-topics:SmartPT')">Smart Portfolio</a> <span>|</span>
#         <a href="http://www.nasdaq.com/forex/" onclick="triggerAsyncOmnitureClickEvent('nav:hot-topics:Currencies')">Currencies</a> <span>|</span>
#         <a href="http://www.nasdaq.com/investing/online-brokers/" onclick="triggerAsyncOmnitureClickEvent('nav:hot-topics:Broker')">Online Broker Center</a>
#     </div>
# 	<!--// End Hot Topics -->
#     <nav id="global_nav">
#         <div id="header_wrap">
#             <div class="logo">
#                 <a href="http://www.nasdaq.com/" target="_self" onclick="triggerAsyncOmnitureClickEvent('nav:links:homepage')">
#                     <span></span>
#                 </a>
#             </div>
#             <div id="nasdaq_login">
#                 <div id="nWelcome" class="floatR">
#                 &nbsp;
#                 </div>
#                 <!--// Begin notifier placeholder -->
#                 <div id="global_notifier" class="floatR">
# 					<div class='ideaMelt' melt-notifier></div>
# 				</div>
#                 <!--// End notifier placeholder -->
#             </div>
#         </div>
#         <div class="clearB"></div>
# ...
# 						&nbsp;Summary Quote<br />
# 						<input type="radio" name="quotepreference" value="dyncharts" onclick="Nasdaq_Quotesearch.confirmUserPref(this.value)">
# 						&nbsp;Interactive Charts<br />
# 						<input type="radio" name="quotepreference" value="default" onclick="Nasdaq_Quotesearch.confirmUserPref(this.value)">
# 						&nbsp;Default Setting<br />
# 					</div>
# 				</div>
# 				<div class="clearB"></div>
# 				<span>
# 					Please note that once you make your selection, it will apply to all future visits to NASDAQ.com.
# 					If, at any time, you are interested in reverting to our default settings, please select Default Setting above.
# 					<br /><br />
# 					If you have any questions or encounter any issues in changing your default settings, please email <a href="mailto:isfeedback@nasdaq.com?Subject=Default%20Settings%20Inquiry">isfeedback@nasdaq.com</a>.
# 				</span>
# 			</div>
# 			<!-- end lightboxness -->
# 			<!-- begin lightboxness -->
# 			<div class="lightbox" id="confirm">
# 				<!-- close button-->
# 				<span class="close">CLOSE<span class="x">X</span></span>
# 				<h4>Please confirm your selection:</h4>
# 				<p>
# 					You have selected to change your default setting for the Quote Search. This will now be your default target page;
# 					unless you change your configuration again, or you delete your
# 					cookies. <b>Are you sure you want to change your settings?</b>
# 				</p>
# 				<div>
# 					<button class="floatL"  onclick="Nasdaq_Quotesearch.confirmHandler('defaultQuote', true)">YES</button>
# 					<button class="floatR"  onclick="Nasdaq_Quotesearch.confirmHandler('defaultQuote', false)">NO</button>
# 				</div>
# 			</div>
# 			<!-- end lightboxness -->
# 		</td>
# 	</tr>
# </table>
# <!-- end lightbox backdrop -->
# <table class="backdrop" id="globalCustomModal">
# 	<tr>
# 		<td>
#             <!-- begin lightboxness -->
#             <div class="lightbox" id="adBlockMsg">
# 				<!-- close button-->
# 				<span class="close" onclick="close_global_modal()">CLOSE<span class="x">X</span></span>
# 				<!-- <h2><center>We have a favor to ask</center></h2> -->
# 				<!-- text -->
# 				<p id="adBlockMsgText">Please disable your ad blocker (or <a href="http://www.nasdaq.com/help/adblock-instructions.aspx">update your settings</a> to ensure that javascript and cookies are enabled), so that we can continue to provide you with the first-rate market news and data you've come to expect from us.</p>
# 			</div>
#             <!-- end lightboxness -->
# 			<!-- begin lightboxness -->
#             <div class="lightbox" id="interstitialAdContainer" style="width:705px;height:575px">
# 				<!-- close button-->
# 				<span class="close" onclick="close_global_modal()">CLOSE<span class="x">X</span></span>
# 				<!-- <h2><center>Sponsor Message</center></h2> -->
# 				<!-- text -->
# 				<p id="interstitialContainer"></p>
# 			</div>
#             <!-- end lightboxness -->
#          </td>
# 	</tr>
# </table>
#
# <!-- Omniture code -->
#
# <!--********************BEGIN  ../includes/omniture.inc***********************-->
#
# <!-- SiteCatalyst code version: H.1.
# Copyright 1997-2005 Omniture, Inc. More info available at http://www.omniture.com -->
# <script language="JavaScript" type="text/javascript" src="http://www.nasdaq.com/includes/s_code-072016v1.js?v=03012016"></script>
#
#
# <script type="text/javascript" language="JavaScript">
#
# <!--
# if(navigator.appVersion.indexOf('MSIE')>=0)document.write(unescape('%3C')+'\!-'+'-')
# //--></script>
#
# <noscript><img
# src="http://nasdaq.122.2O7.net/b/ss/nasdaqprod/1/H.1--NS/0"
# height="1" width="1" border="0" alt="" /></noscript><!--/DO NOT REMOVE/-->
# <!-- End SiteCatalyst code version: H.1. -->
# <!-- setSectionName() moved to js file: masthead_default.js -->
#
#
# <!--*********************End  ../includes/omniture.inc*******************************-->
#
#
# <script type="text/javascript">
# //<![CDATA[
# setSectionName(propVar);
# //]]>
# </script>
#
# <!-- Begin Tynt-->
# <script type="text/javascript">
# if(document.location.protocol=='http:'){
# var Tynt=Tynt||[];Tynt.push('apOVCYiV0r35wBadbiUzgI');
# (function(){var s=document.createElement('script');s.async="async";s.type="text/javascript";s.src='http://tcr.tynt.com/ti.js';var h=document.getElementsByTagName('script')[0];h.parentNode.insertBefore(s,h);})();
# }
# </script>
# <!-- End Tynt-->
#
# <!-- ideamelt resources -->
# <script>
# addScript(ideameltJS,true,"initIMApps()");
# </script>
#
# <!-- DataPoint Media tracking pixel -->
# <script>
# (function() {
# var d=document,h=d.getElementsByTagName('head')[0],s=d.createElement('script'),sc = 'https:' == document.location.protocol ? 'https://' : 'http://';
# s.type='text/javascript';
# s.async=true;
# s.src=sc+'s.dpmsrv.com/dpm_58f0744907ea8bd8e0f51e568f1536289ceb40a5.min.js';
# h.appendChild(s);
# })();
# </script>
#
# <!-- Begin BlueKai Tag -->
# <iframe name="__bkframe" height="0" width="0" frameborder="0" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" src="about:blank"></iframe>
# <script type="text/javascript" src="http://tags.bkrtx.com/js/bk-coretag.js"></script>
# <script type="text/javascript">
#
# bk_addPageCtx('is_dartSite', (typeof(is_dartSite)!=='undefined')?is_dartSite:'');
# bk_addPageCtx('is_dartZone', (typeof(is_dartZone)!=='undefined')?is_dartZone:'');
# bk_addPageCtx('propVar', (typeof(propVar)!=='undefined')?propVar:'');
# bk_addPageCtx('propVar15', (typeof(propVar15)!=='undefined')?propVar15:'');
# bk_addPageCtx('SymbolType', (typeof(SymbolType)!=='undefined')?SymbolType:'');
# bk_addPageCtx('StockIndustry', (typeof(StockIndustry)!=='undefined')?StockIndustry:'');
# bk_addPageCtx('ArticlePrimaryCategory', (typeof(ArticlePrimaryCategory)!=='undefined')?ArticlePrimaryCategory:'');
#
# bk_doJSTag(31843, 1);
# </script>
# <!-- End BlueKai Tag -->
# <!-- Foresee  -->
# <script type="text/javascript" async src="http://www.nasdaq.com/includes/foresee/foresee-trigger.js"></script>
#
# <!--  Quantcast Tag -->
# <script>
#
#  var ezt = ezt ||[];
#
#  (function(){
#    var elem = document.createElement('script');
#    elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://pixel") + ".quantserve.com/aquant.js?a=p-kGNZ2CXTUFYyw";
#    elem.async = true;
#    elem.type = "text/javascript";
#    var scpt = document.getElementsByTagName('script')[0];
#    scpt.parentNode.insertBefore(elem,scpt);
#  }());
#
#
# (function(){
#    var label;
#    if(typeof propVar3=='undefined')
#  		propVar3 = "";
#    if(typeof propVar15=='undefined')
#  		propVar15 = "";
#    if(typeof propVar=='undefined')
# 		propVar = "";
#    label = 'Author.'+propVar3+',Category.'+propVar15+'.'+propVar;
#  ezt.push({qacct: 'p-kGNZ2CXTUFYyw',
# 	   uid: '',
# 	   labels:label
#            });
# }());
#
# </script>
# <noscript>
#   <img src="//pixel.quantserve.com/pixel/p-kGNZ2CXTUFYyw.gif" style="display: none;" border="0" height="1" width="1" alt="Quantcast"/>
# </noscript>
# <!-- End Quantcast Tag -->
#
# <!-- begin Enerprise Florida survey -->
# <script>
# (function(){
# if(document.referrer=="http://www"+host_Extension+".nasdaq.com/markets/ipos/"
# 	&& document.location.href!="http://www"+host_Extension+".nasdaq.com/markets/ipos/"
# 	&& get_cookie_value("EnterpriseFloridaSurvey")==false)
# {
# 	set_cookie_value("EnterpriseFloridaSurvey","true",3);
# 	(function(t,e,s,n){var o,c,a;t.SMCX=t.SMCX||[],e.getElementById(n)||(o=e.getElementsByTagName(s),c=o[o.length-1],a=e.createElement(s),a.type="text/javascript",a.async=!0,a.id=n,a.src=["https:"===location.protocol?"https://":"http://","widget.surveymonkey.com/collect/website/js/DrqdalJhvDd5ACgCO0mDpO1m7_2FEv_2BICPaYzBfwyQJ8_2BsY6t3mPJl0hh2FGypTiFu.js"].join(""),c.parentNode.insertBefore(a,c))})(window,document,"script","smcx-sdk");
# }
# else if(document.location.href=="http://www"+host_Extension+".nasdaq.com/markets/gold.aspx"
# 	&& get_cookie_value("EnterpriseFloridaSurvey")==false)
# {
# 	set_cookie_value("EnterpriseFloridaSurvey","true",7);
# 	(function(e,t,n,o){var s,c,i;e.SMCX=e.SMCX||[],t.getElementById(o)||(s=t.getElementsByTagName(n),c=s[s.length-1],i=t.createElement(n),i.type="text/javascript",i.async=!0,i.id=o,i.src=["https:"===location.protocol?"https://":"http://","widget.surveymonkey.com/collect/website/js/zlERY9yXVqREVYHr6ZdqhDNMqk2NLii_2Fefbn4hZPEGkz2TEDYuhOlBtXpQe_2FgiXz.js"].join(""),c.parentNode.insertBefore(i,c))})(window,document,"script","smcx-sdk");
# }
# })();
# </script>
# <!-- end Enterprise Florida survey -->
#
# <!-- end includes/fixedFooter.inc-->
#
# <!-- START page bottom script -->
# <script language="javascript" type="text/javascript">
#     var sleeptime = 7; var today = new Date(); var timerid = null; var xmlhttp = null;
#     if (today.getDay() == 6 || today.getDay() == 0 || today.getHours() < 9 || today.getHours() > 17)
#     { sleeptime = 9; /*Sleep time during non business hours*/ }
#     else
#     { sleeptime = 7; /*Sleep time during business hours */ }
#     function setCookie(c_name, value, expiredays) { var exdate = new Date(); exdate.setDate(exdate.getDate() + expiredays); document.cookie = c_name + "=" + escape(value) + ((expiredays == null) ? "" : ";expires=" + exdate.toGMTString()); }
#     function getCookie(c_name) { if (document.cookie.length > 0) { c_start = document.cookie.indexOf(c_name + "="); if (c_start != -1) { c_start = c_start + c_name.length + 1; c_end = document.cookie.indexOf(";", c_start); if (c_end == -1) c_end = document.cookie.length; return unescape(document.cookie.substring(c_start, c_end)); } } return ""; }
#     function getQuoteData() {
#
#         var Streaming = getCookie('streamingdata');
#         if (Streaming == "On") {
#             document.getElementById('DynamicSwitch').innerHTML = "Turn Off";
#             setCookie('streamingdata', 'On', 365);
#             getData();
#
#         }
#         else {
#             document.getElementById('DynamicSwitch').innerHTML = "Turn On";
#             setCookie('streamingdata', 'Off', 365);
#         }
#     }
#     function getData() {
#         if (window.XMLHttpRequest) {
#             xmlhttp = new XMLHttpRequest();
#         }
#         else if (window.ActiveXObject) {
#             xmlhttp = new ActiveXObject("Microsoft.XMLHTTP");
#         }
#         if (xmlhttp == null) {
#             alert("Browser does not support dynamic data");
#         }
#         else {
#             var Url = "../quotedll/quote.dll?page=InfoQuotes&mode=stock&symbol=AMZN&selected=AMZN&" + Math.random();
#             xmlhttp.onreadystatechange = UpdateQuoteData;
#             xmlhttp.open("GET", Url, true);
#             xmlhttp.send(null);
#             timerid = self.setTimeout("getQuoteData()", sleeptime * 1000);
#         }
#     }
#     function UpdateQuoteData() {
#         if (xmlhttp.readyState == 4 || xmlhttp.readyState == "complete") {
#             if (xmlhttp.responseText != "") {
#                 var symboldata = new Array();
#                 var changesign = "";
#                 var prepcl = "";
#                 symboldata = xmlhttp.responseText.split("<*>");
#                 for (var i = 1; i < symboldata.length; i++) {
#                     var symbolvalues = new Array();
#                     symbolvalues = symboldata[i].split("|");
#
#                     // Update the Volume
#                     document.getElementById(symbolvalues[0] + "_Volume").innerHTML = symbolvalues[6];
#                     // Market Status
#                     SetQuoteBarTimeStamp(symbolvalues[26]);
#
#                     if (symbolvalues[2].toUpperCase() != 'OTCBB' && symbolvalues[2].toUpperCase() != 'OTHER OTC') {
#                         SetQuoteBarText(symbolvalues[5], symbolvalues[22], symbolvalues[23], symbolvalues[24]);
#                         document.title = symbolvalues[0] + " : $" + symbolvalues[46].toString() + changesign + symbolvalues[22] + " (" + symbolvalues[23] + ")";
#                     } else {
#                         var netch = "";
#                         var pctch = "";
#                         var dispnet = "";
#                         var dispct = "";
#
#                         prepcl =
#                         netch = parseFloat(symbolvalues[46] - prepcl);
#
#                         pctch = netch / prepcl;
#                         dispnet = parseFloat(netch).toFixed(4);
#                         dispct = (pctch * 100).toFixed(2) + "%";
#
#                         if (parseFloat(netch) > 0) {
#                             SetQuoteBarText(symbolvalues[5], dispnet, dispct, "up");
#                             changesign = "+";
#                         }
#                         else if (parseFloat(netch) < 0) {
#                             SetQuoteBarText(symbolvalues[5], dispnet, dispct, "down");
#                             changesign = "-";
#                         }
#                         else {
#                             SetQuoteBarText(symbolvalues[5], dispnet, dispct, "unch");
#                             dispnet = "unch";
#                         }
#
#                         if (netch == "0.0000") {
#                             SetQuoteBarText(symbolvalues[5], dispnet, dispct, "unch");
#                             dispnet = "unch";
#                         }
#
#
#                         if (symbolvalues[6] == "0") {
#                             document.title = symbolvalues[0] + " : $" + prepcl + " (unch)";
#                             SetQuoteBarText(" : $" + prepcl, "unch", "unch", "unch");
#                             dispnet = "unch";
#
#                         } else {
#                             document.title = symbolvalues[0] + " : $" + symbolvalues[46].toString() + changesign + dispnet + " (" + dispct + ")";
#                         }
#
#
#                     }
#                 }
#             }
#         }
#     }
#     function StreamingClick() {
#         var value = document.getElementById('DynamicSwitch').innerHTML;
#         if (value == 'Turn On') {
#             document.getElementById('DynamicSwitch').innerHTML = "Turn Off";
#             setCookie('streamingdata', 'On', 365);
#             getQuoteData();
#         }
#         else {
#             document.getElementById('DynamicSwitch').innerHTML = "Turn On";
#             setCookie('streamingdata', 'Off', 365);
#             clearTimeout(timerid);
#         }
#     }
#     if (document.getElementById('DynamicSwitch') != null)
#         timerid = self.setTimeout("getQuoteData()", sleeptime * 1000);
#     </script>
#    <script type="text/javascript">
#        var tooltiptimer = "";
#        function showDelayedToolTip(eleID) {
#            tooltiptimer = setTimeout("showToolTip('" + eleID + "');", 1000);
#        }
#        function showToolTip(eleID) {
#            document.getElementById(eleID).getElementsByTagName("span")[0].style.visibility = "visible";
#            tooltiptimer = "";
#        }
#        function hideToolTip(eleID) {
#            if (tooltiptimer != "") {
#                clearTimeout(tooltiptimer);
#                tooltiptimer = "";
#            }
#            document.getElementById(eleID).getElementsByTagName("span")[0].style.visibility = "hidden";
#        }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "WebPage",
#     "mainEntity":{
#         "@type":"Corporation",
#         "name":"Amazon.com, Inc. Common Stock",
#         "tickerSymbol":"AMZN"
#     },
#     "breadcrumb":{
#     "@type": "BreadcrumbList",
#     "itemListElement":
#     [
#         {
#             "@type": "ListItem",
#             "position": 1,
#             "item":
#             {
#                 "@type": "WebPage",
#                 "@id": "http://www.nasdaq.com/",
#                 "name": "Home"
#             }
#         },
#         {
#             "@type": "ListItem",
#             "position": 2,
#             "item":
#             {
#                 "@type": "WebPage",
#                 "@id": "http://www.nasdaq.com/quotes/",
#                 "name": "Quotes"
#             }
#         },
#         {
#             "@type": "ListItem",
#             "position": 3,
#             "item":
#             {
#                 "@type": "WebPage",
#                 "@id": "http://www.nasdaq.com/symbol/amzn",
#                 "name": "Symbol"
#             }
#         }
#     ]
# }
# }
# </script>
# <!-- start fly next box -->
# <div id="SQFlyNextBox" class="ideaMelt"></div>
# <!-- end fly next box -->
#
# <!-- END page bottom script -->
#
#
# </body>
# </html>

# %% [markdown]
# It looks like it works, so we should refactor it into a function and then test again. we pass in the `symbol` as input and return what we would print as output.

# %%
def get_html_from_nasdaq(symbol):
    url = 'http://www.nasdaq.com/symbol/' + symbol
    response = requests.get(url)
    if response.ok:
        return response.text
    else:
        return "Error retrieving " + url

# %% [markdown]
# Let's try it out... should work

# %%
html = get_html_from_nasdaq('amzn')
html
# Out:
# '\r\n<!doctype html>\r\n<html lang="en-us" class="inner no-js" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml">\r\n<head>\r\n<script>\r\n(function(){\r\nvar is_chrome;\r\nif(typeof navigator.vendor!="undefined")\r\n\tis_chrome = ((navigator.userAgent.toLowerCase().indexOf(\'chrome\') > -1) &&(navigator.vendor.toLowerCase().indexOf("google") > -1));\r\nelse\r\n\tis_chrome = false;\r\nif(is_chrome)\r\n{\r\n//instart\r\n//copyright Tue Apr 25 2017 17:02:36 GMT+0000 (UTC)\r\n(function(f){(function(){var C="undefined"===typeof IXC_115_9954108064986444||"undefined"===typeof IXC_115_9954108064986444.CanRun||"_115_9954108064986444"!==IXC_115_9954108064986444._115_9954108064986444||IXC_115_9954108064986444.CanRun("abd");if(C)try{(f.IXC_115_9954108064986444=f.IXC_115_9954108064986444||{})._115_9954108064986444="_115_9954108064986444",f[atob("SU5TVEFSVA==")+"_TARGET_NAME"]="abd",f[atob("STExQw==")]=f[atob("STExQw==")]||{}}catch(O){console.error(O)}else{var D="abd"!==f[atob("SU5TVEFSVA==")+\r\n"_TARGET_NAME"],r="double nanovisor injection: abd after "+f[atob("SU5TVEFSVA==")+"_TARGET_NAME"];D&&console.log(r);"function"!==typeof f[atob("SU5TVEFSVA==")].Init&&(f[atob("SU5TVEFSVA==")].Init=function(){D&&console.error("ignored Init call after "+r)})}return C})()&&function(){function C(b,a){return"object"!==typeof a||Array.isArray(a)?a:la(a,b,C)}function D(){return[]}function r(){return 1===t.c}function O(){return 4===t.c}function P(b){x=new ma(b);t=x.V;E=x.Xa;return x}function k(b){return b.split("").filter(function(a,\r\nb){return 0===b%2}).reverse().join("")}function y(b,a,c){if(!b&&(console.error(a),(b=D(2))&&0<b.length&&console.log(b),na&&!c))throw a;}function l(b,a){function c(){this.constructor=b}Ra(b,a);b.prototype=null===a?Object.create(a):(c.prototype=a.prototype,new c)}function u(b,a){b=b.split(".");for(var c=f||{},d,e=0;e<b.length-1;++e){d=b[e];if(!c)return;var g=c[d]||{};try{c[d]=g}catch(h){}c=g}d=b[b.length-1];if(c){y(!!d,"In Export, name not defined");try{c[d]=a}catch(h){}}}function Sa(b){b=b.split(".");\r\nfor(var a=f,c,d=0;a&&d<b.length-1;++d)if(c=b[d],a=a[c],!a)return;c=b[b.length-1];y(!!a&&!!c,"In Deport, obj or name not defined");try{var e=Object.getOwnPropertyDescriptor(a,c);e&&e.writable&&delete a[c]||(a[c]=void 0)}catch(g){}}function ca(){return f.document.currentScript||f.document.scripts[document.scripts.length-1]}function Ta(){if(F&&G&&F.nextSibling===G)for(var b=G.nextSibling,a=F;a!=b;){var c=a,a=a.nextSibling;c.parentNode.removeChild(c)}Sa(da);u(da+".Init",function(){})}function p(b,a,c){var d=\r\n{};d.Type=b;d[m]=a;c&&(d[oa]=c);return d}function Ua(){return new z(function(b){function a(a){var d=!1;"load"===a.type?d=!1:"error"===a.type&&(d=!0);b(p(Va,d,a.currentTarget.src));c&&(a=a.target)&&a.parentNode&&a.parentNode.removeChild(a)}var c=4===t.c&&3===E.c,d=document.createElement("img");d.onload=a;d.onerror=a;var e=Math.floor(Math.random()*H.length);d.src=H[e]+"?"+pa[Math.floor(Math.random()*pa.length)];c&&document.body.appendChild(d);1<H.length&&H.splice(e,1)})}function qa(b,a){return new z(function(c){var d=\r\n"script"===b?Wa:Xa,e=O();if(r()||e){var g;e&&(g=setTimeout(function(){c(p(d,!1,"Timed out on error"))},500));var h=function(a){e&&clearTimeout(g);var b=!1;"load"===a.type?b=!1:"error"===a.type&&(b=!0);c(p(d,b,a.currentTarget.href));(a=a.target)&&a.parentNode&&a.parentNode.removeChild(a)},f=document.createElement("link");f.onload=h;f.onerror=h;f.rel="preload";f.as=b;h=Math.floor(Math.random()*a.length);f.href=a[h];v&&v.parentNode&&v.parentNode.insertBefore(f,v);1<a.length&&a.splice(h,1)}else c(p(d,\r\n!1,"Neither Chrome nor Safari"))})}function Ya(){new z(function(b){var a=document.createElement("iframe");a.src=f.atob("Ly90cGMuZ29vZ2xlc3luZGljYXRpb24uY29tL3NhZmVmcmFtZS8=")+f.atob("MS0wLTU=")+f.atob("L2h0bWwvY29udGFpbmVyLmh0bWw=");a.style.height="1px";a.style.width="1px";a.style.left="-555px";a.style.top="-555px";a.style.display="block";a.scrolling="no";a.frameBorder="0";var c=f.atob( ...

# %% [markdown]
# ## use BeautifulSoup4 to extract data from the site
#
# Next we want to take `html` and extract out the meaningful bits. This is the part that requires time and patience. You'll need to use a browser's developer tools to find the important CSS selectors so you can retrieve the data.
#
# For simplicity's sake, we've done this for you. Feel free to open http://www.nasdaq.com/symbol/amzn in your browser's developer tools and locate each of these three selectors:

# %%
soup = BeautifulSoup(html, "lxml")
name = soup.select("div#qwidget_pageheader h1")[0].text
price = soup.select("div#qwidget_lastsale")[0].text
change = soup.select("div#qwidget_percent")[0].text
print(name,price,change)
# Out:
# Amazon.com, Inc. Common Stock Quote & Summary Data $918.38 1%

# %% [markdown]
# We can't easily return 3 values from a function (actually you can in python, but we don't like to teach you that) so instead we will create a dictionary of these values first:

# %%
soup = BeautifulSoup(html, "lxml")
name = soup.select("div#qwidget_pageheader h1")[0].text
price = soup.select("div#qwidget_lastsale")[0].text
change = soup.select("div#qwidget_percent")[0].text
stock= { 'Name' : name,
        "Price" : price,
        "Change" : change
}

print(stock)
# Out:
# {'Name': 'Amazon.com, Inc. Common Stock Quote & Summary Data', 'Change': '1%', 'Price': '$918.38'}

# %% [markdown]
# Once again, its time to refactor this into a function we take `html` as input (its the one thing we require to make this code work) and `stock` as output (since it is what we print.

# %%
def extract_stock_data(html):
    soup = BeautifulSoup(html, "lxml")
    name = soup.select("div#qwidget_pageheader h1")[0].text
    price = soup.select("div#qwidget_lastsale")[0].text
    change = soup.select("div#qwidget_percent")[0].text
    stock= { 'Name' : name,
            "Price" : price,
            "Change" : change
    }

    return stock

# %% [markdown]
# And we should test out our new function:

# %%
stock = extract_stock_data(html)
print(stock)
# Out:
# {'Name': 'Amazon.com, Inc. Common Stock Quote & Summary Data', 'Change': '1%', 'Price': '$918.38'}

# %% [markdown]
# ## Putting it all together
#
# Now you need to put it all together. Write a program to:
#
# 1. input a stock symbol on the NASDAQ exchange
# 2. get the html from the stock symbol on the NASDAQ website
# 3. extract the stock data from the html
# 4. print out the stock informtiom
#
# The program should work like this:
#
# ```
# Enter a stock symbol on the NASDAQ Exchange: amzn
# Name: Amazon.com, Inc. Common Stock Quote & Summary Data
# Price: $852.53
# Change: 0.24%
# ```

# %%
# todo write code here:
symbol = input("Enter a stock symbol on the NASDAQ exchange")
def get_html_from_nasdaq(symbol):
    url = 'http://www.nasdaq.com/symbol/' + symbol
    response = requests.get(url)
    if response.ok:
        return response.text
    else:
        return "Error retrieving " + url
soup = BeautifulSoup(html, "lxml")
name = soup.select("div#qwidget_pageheader h1")[0].text
price = soup.select("div#qwidget_lastsale")[0].text
change = soup.select("div#qwidget_percent")[0].text
print(name,price,change)
# Out:
# Enter a stock symbol on the NASDAQ exchangeamzn
# Amazon.com, Inc. Common Stock Quote & Summary Data $918.38 1%
